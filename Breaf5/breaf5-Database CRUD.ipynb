# %% [markdown]
# # Créations des tables populations et countries à partir d'un ficher .csv et .txt

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## TABLE POPULATIONS

# %%
populations = pd.read_csv('breaf5-populations.csv')

# %%
populations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16060 entries, 0 to 16059
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    16060 non-null  object
#  1   INDICATOR   16060 non-null  object
#  2   SUBJECT     16060 non-null  object
#  3   MEASURE     16060 non-null  object
#  4   FREQUENCY   16060 non-null  object
#  5   TIME        16060 non-null  int64
#  6   Value       16060 non-null  float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1003.9+ KB

# %%
len(populations.columns)
# Out:
# 8

# %%
populations.SUBJECT.unique()
# Out:
# array(['TOT', 'MEN', 'WOMEN'], dtype=object)

# %% [markdown]
# Les valeurs de la colonne SUBJECT sont transformés en valeur numérique pour pouvoir les supprimer par la suite (ne semble pas fonctionner avec des valeurs de type str). Cela permet de supprimer les lignes ne recensant qu'une partie de la population.

# %%
populations.SUBJECT.replace(['TOT', 'MEN', 'WOMEN'], [1,2,3], inplace=True)

# %%
populations.drop(populations[(populations.SUBJECT > 1)].index, inplace=True)

# %%
populations.SUBJECT.unique()
# Out:
# array([1], dtype=int64)

# %%
populations.MEASURE.unique()
# Out:
# array(['AGRWTH', 'MLN_PER'], dtype=object)

# %% [markdown]
# On fait la même avec la colonne MEASURE pour supprimer ls lignes ayant la valeur AGRWTH.

# %%
populations.MEASURE.replace(['MLN_PER', 'AGRWTH'], [1,2], inplace=True)

# %%
populations.drop(populations[(populations.MEASURE > 1)].index, inplace=True)

# %%
populations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4029 entries, 143 to 15987
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    4029 non-null   object
#  1   INDICATOR   4029 non-null   object
#  2   SUBJECT     4029 non-null   int64
#  3   MEASURE     4029 non-null   int64
#  4   FREQUENCY   4029 non-null   object
#  5   TIME        4029 non-null   int64
#  6   Value       4029 non-null   float64
#  7   Flag Codes  0 non-null      float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 283.3+ KB

# %% [markdown]
# Multiplication des valeurs par un million pour les mettre à l'échelle.

# %%
populations.Value = round(populations.Value * 1000000, 0)

# %%
populations.head()
# Out:
#     LOCATION INDICATOR  SUBJECT  MEASURE FREQUENCY  TIME      Value  \
# 143      AUS       POP        1        1         A  1950  8178700.0
# 144      AUS       POP        1        1         A  1951  8421700.0
# 145      AUS       POP        1        1         A  1952  8636500.0
# 146      AUS       POP        1        1         A  1953  8815300.0
# 147      AUS       POP        1        1         A  1954  8986500.0
#
#      Flag Codes
# 143         NaN
# 144         NaN
# 145         NaN
# 146         NaN
# 147         NaN

# %% [markdown]
# Création d'un ficher csv ne contenant que les lignes et colonnes d'intérêt pour le breaf.

# %%
populations[['LOCATION', 'TIME', 'Value']].to_csv('breaf5-populations_drop', index=False, encoding='utf-8')

# %%
populations_drop = pd.read_csv('breaf5-populations_drop', index_col=False)
populations_drop.head()
# Out:
#   LOCATION  TIME      Value
# 0      AUS  1950  8178700.0
# 1      AUS  1951  8421700.0
# 2      AUS  1952  8636500.0
# 3      AUS  1953  8815300.0
# 4      AUS  1954  8986500.0

# %%
populations_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4029 entries, 0 to 4028
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LOCATION  4029 non-null   object
#  1   TIME      4029 non-null   int64
#  2   Value     4029 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 94.6+ KB

# %% [markdown]
# Envoie dans la base de donnée déjà créé à l'avance 'CountriesDatas' dans PHPmyadmin. Pour cela, une table 'populations' est créée avec 4 colonnes dont un index auto-incrémenté en clé primaire, puis les données sont envoyés dans la table nouvellement créée 'populations'.

# %%
import mysql.connector as mysql
from mysql.connector import Error

user = 'root'
password = 'example'
host = 'localhost'
port = '3308'
database = 'CountriesDatas'

try:
    conn = mysql.connect(host=host, port=port, user=user, password=password, database=database)
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS populations;')
        print('Creating table....')
        cursor.execute("CREATE TABLE populations(id INT PRIMARY KEY NOT NULL AUTO_INCREMENT, LOCATION VARCHAR(10) NOT NULL, TIME year NOT NULL, Value BIGINT NOT NULL);")
        print("Table is created....")
        for i,row in populations_drop.iterrows():
            sql = "INSERT INTO populations (LOCATION, TIME, Value) VALUES (%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            conn.commit()
        cursor.close()
        conn.close()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('countriesdatas',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %% [markdown]
# ## TABLE COUNTRIES

# %%
countries = pd.read_fwf('breaf5-country.txt')
countries
# Out:
#                        colonne
# 0           ABW __****__ Aruba
# 1     AFG __****__ Afghanistan
# 2         AFRI __****__ Africa
# 3          AGO __****__ Angola
# 4        AIA __****__ Anguilla
# ..                         ...
# 227         WSM __****__ Samoa
# 228         YEM __****__ Yemen
# 229  ZAF __****__ South Africa
# 230        ZMB __****__ Zambia
# 231      ZWE __****__ Zimbabwe
#
# [232 rows x 1 columns]

# %% [markdown]
# Création de deux nouvelles colonnes pour accueillir les données extraites des données d'origine (j'avoue, j'ai triché, j'ai rajouté manuellement une ligne au fichier .txt, car la première ligne devient le titre de la table).

# %%
countries['code'] = 0
countries['name'] = 0

# %% [markdown]
# Les deux boucles suivantes permettent d'extraire les données correspondant à 'code' et 'name' grâce à des regex.

# %%
for i in countries:
    countries.code = countries.colonne.str.extract('([A-Z]+)\s')

# %%
for i in countries:
    countries.name = countries.colonne.str.extract('\s([A-Za-z\s]+)')

# %%
countries
# Out:
#                        colonne  code          name
# 0           ABW __****__ Aruba   ABW         Aruba
# 1     AFG __****__ Afghanistan   AFG   Afghanistan
# 2         AFRI __****__ Africa  AFRI        Africa
# 3          AGO __****__ Angola   AGO        Angola
# 4        AIA __****__ Anguilla   AIA      Anguilla
# ..                         ...   ...           ...
# 227         WSM __****__ Samoa   WSM         Samoa
# 228         YEM __****__ Yemen   YEM         Yemen
# 229  ZAF __****__ South Africa   ZAF  South Africa
# 230        ZMB __****__ Zambia   ZMB        Zambia
# 231      ZWE __****__ Zimbabwe   ZWE      Zimbabwe
#
# [232 rows x 3 columns]

# %%
countries[['code', 'name']].to_csv('breaf5-countries_drop', index=False, encoding='utf-8')

# %%
countries_drop = pd.read_csv('breaf5-countries_drop', index_col=False)
countries_drop.head()
# Out:
#    code         name
# 0   ABW        Aruba
# 1   AFG  Afghanistan
# 2  AFRI       Africa
# 3   AGO       Angola
# 4   AIA     Anguilla

# %%
import mysql.connector as mysql
from mysql.connector import Error

user = 'root'
password = 'example'
host = 'localhost'
port = '3308'
database = 'CountriesDatas'

try:
    conn = mysql.connect(host=host, port=port, user=user, password=password, database=database)
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS countries;')
        print('Creating table....')
        cursor.execute("CREATE TABLE countries(code VARCHAR(10) PRIMARY KEY NOT NULL, name VARCHAR(50) NOT NULL);")
        print("Table is created....")
        for i,row in countries_drop.iterrows():
            sql = "INSERT INTO countries VALUES (%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            conn.commit()
            cursor.close()
            conn.close()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('countriesdatas',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %% [markdown]
# # JOIN de la table 'populations' avec la table 'countries'.

# %%
try:
    conn = mysql.connect(host=host, port=port, user=user, password=password, database=database)
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute(f"""SELECT populations.id, countries.name, populations.TIME, populations.Value FROM populations JOIN countries 
                            ON populations.LOCATION = countries.code""")
        population_country = cursor.fetchall()
        cursor.close()
        conn.close()
        
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('countriesdatas',)

# %%
for i in population_country:
    print(i)
# Out:
# (1, 'Australia', 1950, 8178700)
# (2, 'Australia', 1951, 8421700)
# (3, 'Australia', 1952, 8636500)
# (4, 'Australia', 1953, 8815300)
# (5, 'Australia', 1954, 8986500)
# (6, 'Australia', 1955, 9199700)
# (7, 'Australia', 1956, 9425500)
# (8, 'Australia', 1957, 9640200)
# (9, 'Australia', 1958, 9842400)
# (10, 'Australia', 1959, 10056400)
# (11, 'Australia', 1960, 10275000)
# (12, 'Australia', 1961, 10508200)
# (13, 'Australia', 1962, 10700500)
# (14, 'Australia', 1963, 10906900)
# (15, 'Australia', 1964, 11121600)
# (16, 'Australia', 1965, 11340900)
# (17, 'Australia', 1966, 11599498)
# (18, 'Australia', 1967, 11799078)
# (19, 'Australia', 1968, 12008635)
# (20, 'Australia', 1969, 12263014)
# (21, 'Australia', 1970, 12507349)
# (22, 'Australia', 1971, 13067265)
# (23, 'Australia', 1972, 13303664)
# (24, 'Australia', 1973, 13504538)
# (25, 'Australia', 1974, 13722571)
# (26, 'Australia', 1975, 13892995)
# (27, 'Australia', 1976, 14033083)
# (28, 'Australia', 1977, 14192234)
# (29, 'Australia', 1978, 14359255)
# (30, 'Australia', 1979, 14515729)
# (31, 'Australia', 1980, 14695356)
# (32, 'Australia', 1981, 14923260)
# (33, 'Australia', 1982, 15184247)
# (34, 'Australia', 1983, 15393472)
# (35, 'Australia', 1984, 15579391)
# (36, 'Australia', 1985, 15788312)
# (37, 'Australia', 1986, 16018350)
# (38, 'Australia', 1987, 16263874)
# (39, 'Australia', 1988, 16532164)
# (40, 'Australia', 1989, 16814416)
# (41, 'Australia', 1990, 17065128)
# (42, 'Australia', 1991, 17284036)
# (43, 'Australia', 1992, 17478635)
# (44, 'Australia', 1993, 17634808)
# (45, 'Australia', 1994, 17805468)
# (46, 'Australia', 1995, 18004882)
# (47, 'Australia', 1996, 18224767)
# (48, 'Australia', 1997, 18423037)
# (49, 'Australia', 1998, 18607584)
# (50, 'Australia', 1999, 18812264)
# (51, 'Australia', 2000, 19028802)
# (52, 'Australia', 2001, 19274701)
# (53, 'Australia', 2002, 19495210)
# (54, 'Australia', 2003, 19720737)
# (55, 'Australia', 2004, 19932722)
# (56, 'Australia', 2005, 20176844)
# (57, 'Australia', 2006, 20450966)
# (58, 'Australia', 2007, 20827622)
# (59, 'Australia', 2008, 21249199)
# (60, 'Australia', 2009, 21691653)
# (61, 'Australia', 2010, 22031750)
# (62, 'Australia', 2011, 22340024)
# (63, 'Australia', 2012, 22733465)
# (64, 'Australia', 2013, 23128129)
# (65, 'Australia', 2014, 23475686)
# (66, 'Australia', 2015, 23815995)
# (67, 'Australia', 2016, 24190907)
# (68, 'Australia', 2017, 24601860)
# (69, 'Australia', 2018, 24982688)
# (70, 'Australia', 2019, 25365745)
# (71, 'Australia', 2020, 25693267)
# (72, 'Australia', 2021, 25738142)
# (73, 'Austria', 1950, 6935100)
# (74, 'Austria', 1951, 6935451)
# (75, 'Austria', 1952, 6927772)
# (76, 'Austria', 1953, 6932483)
# (77, 'Austria', 1954, 6940209)
# (78, 'Austria', 1955, 6946885)
# (79, 'Austria', 1956, 6952359)
# (80, 'Austria', 1957, 6965860)
# (81, 'Austria', 1958, 6987358)
# (82, 'Austria', 1959, 7014331)
# (83, 'Austria', 1960, 7047539)
# (84, 'Austria', 1961, 7086299)
# (85, 'Austria', 1962, 7129864)
# (86, 'Austria', 1963, 7175811)
# (87, 'Austria', 1964, 7223801)
# (88, 'Austria', 1965, 7270889)
# (89, 'Austria', 1966, 7322066)
# (90, 'Austria', 1967, 7376998)
# (91, 'Austria', 1968, 7415403)
# (92, 'Austria', 1969, 7441055)
# (93, 'Austria', 1970, 7467086)
# (94, 'Austria', 1971, 7500482)
# (95, 'Austria', 1972, 7544201)
# (96, 'Austria', 1973, 7586115)
# (97, 'Austria', 1974, 7599038)
# (98, 'Austria', 1975, 7578903)
# (99, 'Austria', 1976, 7565525)
# (100, 'Austria', 1977, 7568430)
# (101, 'Austria', 1978, 7562305)
# (102, 'Austria', 1979, 7549425)
# (103, 'Austria', 1980, 7549433)
# (104, 'Austria', 1981, 7568710)
# (105, 'Austria', 1982, 7574140)
# (106, 'Austria', 1983, 7561910)
# (107, 'Austria', 1984, 7561434)
# (108, 'Austria', 1985, 7564984)
# (109, 'Austria', 1986, 7569794)
# (110, 'Austria', 1987, 7574586)
# (111, 'Austria', 1988, 7585317)
# (112, 'Austria', 1989, 7619566)
# (113, 'Austria', 1990, 7677850)
# (114, 'Austria', 1991, 7754891)
# (115, 'Austria', 1992, 7840709)
# (116, 'Austria', 1993, 7905632)
# (117, 'Austria', 1994, 7936118)
# (118, 'Austria', 1995, 7948278)
# (119, 'Austria', 1996, 7959016)
# (120, 'Austria', 1997, 7968041)
# (121, 'Austria', 1998, 7976789)
# (122, 'Austria', 1999, 7992323)
# (123, 'Austria', 2000, 8011566)
# (124, 'Austria', 2001, 8042293)
# (125, 'Austria', 2002, 8082121)
# (126, 'Austria', 2003, 8118245)
# (127, 'Austria', 2004, 8169441)
# (128, 'Austria', 2005, 8225278)
# (129, 'Austria', 2006, 8267948)
# (130, 'Austria', 2007, 8295189)
# (131, 'Austria', 2008, 8321541)
# (132, 'Austria', 2009, 8341483)
# (133, 'Austria', 2010, 8361069)
# (134, 'Austria', 2011, 8388534)
# (135, 'Austria', 2012, 8426311)
# (136, 'Austria', 2013, 8477230)
# (137, 'Austria', 2014, 8543932)
# (138, 'Austria', 2015, 8629519)
# (139, 'Austria', 2016, 8739806)
# (140, 'Austria', 2017, 8795073)
# (141, 'Austria', 2018, 8837707)
# (142, 'Austria', 2019, 8877637)
# (143, 'Austria', 2020, 8916845)
# (144, 'Austria', 2021, 8951520)
# (145, 'Belgium', 1950, 8639369)
# (146, 'Belgium', 1951, 8678386)
# (147, 'Belgium', 1952, 8730405)
# (148, 'Belgium', 1953, 8777873)
# (149, 'Belgium', 1954, 8819374)
# (150, 'Belgium', 1955, 8868451)
# (151, 'Belgium', 1956, 8923800)
# (152, 'Belgium', 1957, 8989050)
# (153, 'Belgium', 1958, 9052650)
# (154, 'Belgium', 1959, 9103712)
# (155, 'Belgium', 1960, 9153490)
# (156, 'Belgium', 1961, 9183948)
# (157, 'Belgium', 1962, 9220578)
# (158, 'Belgium', 1963, 9289770)
# (159, 'Belgium', 1964, 9378114)
# (160, 'Belgium', 1965, 9463668)
# (161, 'Belgium', 1966, 9527808)
# (162, 'Belgium', 1967, 9580991)
# (163, 'Belgium', 1968, 9618756)
# (164, 'Belgium', 1969, 9646033)
# (165, 'Belgium', 1970, 9655550)
# (166, 'Belgium', 1971, 9673162)
# (167, 'Belgium', 1972, 9711115)
# (168, 'Belgium', 1973, 9741721)
# (169, 'Belgium', 1974, 9772420)
# (170, 'Belgium', 1975, 9800700)
# (171, 'Belgium', 1976, 9818228)
# (172, 'Belgium', 1977, 9830358)
# (173, 'Belgium', 1978, 9839534)
# (174, 'Belgium', 1979, 9848382)
# (175, 'Belgium', 1980, 9859243)
# (176, 'Belgium', 1981, 9858982)
# (177, 'Belgium', 1982, 9856303)
# (178, 'Belgium', 1983, 9855521)
# (179, 'Belgium', 1984, 9855372)
# (180, 'Belgium', 1985, 9858309)
# (181, 'Belgium', 1986, 9861824)
# (182, 'Belgium', 1987, 9870234)
# (183, 'Belgium', 1988, 9901665)
# (184, 'Belgium', 1989, 9937697)
# (185, 'Belgium', 1990, 9967378)
# (186, 'Belgium', 1991, 10004486)
# (187, 'Belgium', 1992, 10045165)
# (188, 'Belgium', 1993, 10084479)
# (189, 'Belgium', 1994, 10115601)
# (190, 'Belgium', 1995, 10136814)
# (191, 'Belgium', 1996, 10156641)
# (192, 'Belgium', 1997, 10181246)
# (193, 'Belgium', 1998, 10203012)
# (194, 'Belgium', 1999, 10226419)
# (195, 'Belgium', 2000, 10251247)
# (196, 'Belgium', 2001, 10286571)
# (197, 'Belgium', 2002, 10332783)
# (198, 'Belgium', 2003, 10376130)
# (199, 'Belgium', 2004, 10421133)
# (200, 'Belgium', 2005, 10478617)
# (201, 'Belgium', 2006, 10547956)
# (202, 'Belgium', 2007, 10625701)
# (203, 'Belgium', 2008, 10709976)
# (204, 'Belgium', 2009, 10796498)
# (205, 'Belgium', 2010, 10895589)
# (206, 'Belgium', 2011, 10993616)
# (207, 'Belgium', 2012, 11067748)
# (208, 'Belgium', 2013, 11125033)
# (209, 'Belgium', 2014, 11179778)
# (210, 'Belgium', 2015, 11238474)
# (211, 'Belgium', 2016, 11295003)
# (212, 'Belgium', 2017, 11349081)
# (213, 'Belgium', 2018, 11403740)
# (214, 'Belgium', 2019, 11462023)
# (215, 'Belgium', 2020, 11506938)
# (216, 'Belgium', 2021, 11552615)
# (217, 'Canada', 1950, 14018606)
# (218, 'Canada', 1951, 14318204)
# (219, 'Canada', 1952, 14776291)
# (220, 'Canada', 1953, 15169815)
# (221, 'Canada', 1954, 15620550)
# (222, 'Canada', 1955, 16040090)
# (223, 'Canada', 1956, 16431419)
# (224, 'Canada', 1957, 16970940)
# (225, 'Canada', 1958, 17450075)
# (226, 'Canada', 1959, 17861347)
# (227, 'Canada', 1960, 18256447)
# (228, 'Canada', 1961, 18634666)
# (229, 'Canada', 1962, 18989309)
# (230, 'Canada', 1963, 19347231)
# (231, 'Canada', 1964, 19719595)
# (232, 'Canada', 1965, 20084314)
# (233, 'Canada', 1966, 20420867)
# (234, 'Canada', 1967, 20795138)
# (235, 'Canada', 1968, 21129417)
# (236, 'Canada', 1969, 21439830)
# (237, 'Canada', 1970, 21746497)
# (238, 'Canada', 1971, 21962032)
# (239, 'Canada', 1972, 22218463)
# (240, 'Canada', 1973, 22491777)
# (241, 'Canada', 1974, 22807969)
# (242, 'Canada', 1975, 23143275)
# (243, 'Canada', 1976, 23449808)
# (244, 'Canada', 1977, 23725843)
# (245, 'Canada', 1978, 23963203)
# (246, 'Canada', 1979, 24201544)
# (247, 'Canada', 1980, 24515667)
# (248, 'Canada', 1981, 24819915)
# (249, 'Canada', 1982, 25116942)
# (250, 'Canada', 1983, 25366451)
# (251, 'Canada', 1984, 25607053)
# (252, 'Canada', 1985, 25842116)
# (253, 'Canada', 1986, 26100278)
# (254, 'Canada', 1987, 26446601)
# (255, 'Canada', 1988, 26791747)
# (256, 'Canada', 1989, 27276781)
# (257, 'Canada', 1990, 27691138)
# (258, 'Canada', 1991, 28037420)
# (259, 'Canada', 1992, 28371264)
# (260, 'Canada', 1993, 28684764)
# (261, 'Canada', 1994, 29000663)
# (262, 'Canada', 1995, 29302311)
# (263, 'Canada', 1996, 29610218)
# (264, 'Canada', 1997, 29905948)
# (265, 'Canada', 1998, 30155173)
# (266, 'Canada', 1999, 30401286)
# (267, 'Canada', 2000, 30685730)
# (268, 'Canada', 2001, 31020902)
# (269, 'Canada', 2002, 31360079)
# (270, 'Canada', 2003, 31644028)
# (271, 'Canada', 2004, 31940655)
# (272, 'Canada', 2005, 32243753)
# (273, 'Canada', 2006, 32571174)
# (274, 'Canada', 2007, 32889025)
# (275, 'Canada', 2008, 33247118)
# (276, 'Canada', 2009, 33628895)
# (277, 'Canada', 2010, 34004889)
# (278, 'Canada', 2011, 34339328)
# (279, 'Canada', 2012, 34714222)
# (280, 'Canada', 2013, 35082954)
# (281, 'Canada', 2014, 35437435)
# (282, 'Canada', 2015, 35702908)
# (283, 'Canada', 2016, 36109487)
# (284, 'Canada', 2017, 36545236)
# (285, 'Canada', 2018, 37065084)
# (286, 'Canada', 2019, 37601230)
# (287, 'Canada', 2020, 38037204)
# (288, 'Canada', 2021, 38246108)
# (289, 'Czech Republic', 1950, 8925122)
# (290, 'Czech Republic', 1951, 9023170)
# (291, 'Czech Republic', 1952, 9125183)
# (292, 'Czech Republic', 1953, 9220908)
# (293, 'Czech Republic', 1954, 9290617)
# (294, 'Czech Republic', 1955, 9365969)
# (295, 'Czech Republic', 1956, 9442040)
# (296, 'Czech Republic', 1957, 9513758)
# (297, 'Czech Republic', 1958, 9574650)
# (298, 'Czech Republic', 1959, 9618554)
# (299, 'Czech Republic', 1960, 9659818)
# (300, 'Czech Republic', 1961, 9588016)
# (301, 'Czech Republic', 1962, 9621808)
# (302, 'Czech Republic', 1963, 9668741)
# (303, 'Czech Republic', 1964, 9730019)
# (304, 'Czech Republic', 1965, 9785102)
# (305, 'Czech Republic', 1966, 9826188)
# (306, 'Czech Republic', 1967, 9854241)
# (307, 'Czech Republic', 1968, 9877632)
# (308, 'Czech Republic', 1969, 9896695)
# (309, 'Czech Republic', 1970, 9805157)
# (310, 'Czech Republic', 1971, 9830602)
# (311, 'Czech Republic', 1972, 9868379)
# (312, 'Czech Republic', 1973, 9919519)
# (313, 'Czech Republic', 1974, 9994761)
# (314, 'Czech Republic', 1975, 10062366)
# (315, 'Czech Republic', 1976, 10128220)
# (316, 'Czech Republic', 1977, 10189312)
# (317, 'Czech Republic', 1978, 10245686)
# (318, 'Czech Republic', 1979, 10296489)
# (319, 'Czech Republic', 1980, 10326792)
# (320, 'Czech Republic', 1981, 10303208)
# (321, 'Czech Republic', 1982, 10314321)
# (322, 'Czech Republic', 1983, 10322823)
# (323, 'Czech Republic', 1984, 10330481)
# (324, 'Czech Republic', 1985, 10336742)
# (325, 'Czech Republic', 1986, 10340737)
# (326, 'Czech Republic', 1987, 10348834)
# (327, 'Czech Republic', 1988, 10356359)
# (328, 'Czech Republic', 1989, 10362257)
# (329, 'Czech Republic', 1990, 10362740)
# (330, 'Czech Republic', 1991, 10308682)
# (331, 'Czech Republic', 1992, 10317807)
# (332, 'Czech Republic', 1993, 10330607)
# (333, 'Czech Republic', 1994, 10336162)
# (334, 'Czech Republic', 1995, 10330759)
# (335, 'Czech Republic', 1996, 10315353)
# (336, 'Czech Republic', 1997, 10303642)
# (337, 'Czech Republic', 1998, 10294943)
# (338, 'Czech Republic', 1999, 10282784)
# (339, 'Czech Republic', 2000, 10272503)
# (340, 'Czech Republic', 2001, 10224192)
# (341, 'Czech Republic', 2002, 10200774)
# (342, 'Czech Republic', 2003, 10201651)
# (343, 'Czech Republic', 2004, 10206923)
# (344, 'Czech Republic', 2005, 10234092)
# (345, 'Czech Republic', 2006, 10266646)
# (346, 'Czech Republic', 2007, 10322689)
# (347, 'Czech Republic', 2008, 10429692)
# (348, 'Czech Republic', 2009, 10491492)
# (349, 'Czech Republic', 2010, 10517247)
# (350, 'Czech Republic', 2011, 10496672)
# (351, 'Czech Republic', 2012, 10509286)
# (352, 'Czech Republic', 2013, 10510719)
# (353, 'Czech Republic', 2014, 10524783)
# (354, 'Czech Republic', 2015, 10542942)
# (355, 'Czech Republic', 2016, 10565284)
# (356, 'Czech Republic', 2017, 10589526)
# (357, 'Czech Republic', 2018, 10626430)
# (358, 'Czech Republic', 2019, 10669324)
# (359, 'Czech Republic', 2020, 10700155)
# (360, 'Czech Republic', 2021, 10500850)
# (361, 'Denmark', 1950, 4268468)
# (362, 'Denmark', 1951, 4300376)
# (363, 'Denmark', 1952, 4332355)
# (364, 'Denmark', 1953, 4369279)
# (365, 'Denmark', 1954, 4406576)
# (366, 'Denmark', 1955, 4439006)
# (367, 'Denmark', 1956, 4466527)
# (368, 'Denmark', 1957, 4489871)
# (369, 'Denmark', 1958, 4516287)
# (370, 'Denmark', 1959, 4548660)
# (371, 'Denmark', 1960, 4579603)
# (372, 'Denmark', 1961, 4611690)
# (373, 'Denmark', 1962, 4647733)
# (374, 'Denmark', 1963, 4684481)
# (375, 'Denmark', 1964, 4722074)
# (376, 'Denmark', 1965, 4759011)
# (377, 'Denmark', 1966, 4797381)
# (378, 'Denmark', 1967, 4835358)
# (379, 'Denmark', 1968, 4864879)
# (380, 'Denmark', 1969, 4891860)
# (381, 'Denmark', 1970, 4928748)
# (382, 'Denmark', 1971, 4963126)
# (383, 'Denmark', 1972, 4991596)
# (384, 'Denmark', 1973, 5021862)
# (385, 'Denmark', 1974, 5045298)
# (386, 'Denmark', 1975, 5059862)
# (387, 'Denmark', 1976, 5072597)
# (388, 'Denmark', 1977, 5088420)
# (389, 'Denmark', 1978, 5104248)
# (390, 'Denmark', 1979, 5116802)
# (391, 'Denmark', 1980, 5123027)
# (392, 'Denmark', 1981, 5121572)
# (393, 'Denmark', 1982, 5117810)
# (394, 'Denmark', 1983, 5114297)
# (395, 'Denmark', 1984, 5111619)
# (396, 'Denmark', 1985, 5113691)
# (397, 'Denmark', 1986, 5120534)
# (398, 'Denmark', 1987, 5127024)
# (399, 'Denmark', 1988, 5129517)
# (400, 'Denmark', 1989, 5132594)
# (401, 'Denmark', 1990, 5140939)
# (402, 'Denmark', 1991, 5154298)
# (403, 'Denmark', 1992, 5171370)
# (404, 'Denmark', 1993, 5189377)
# (405, 'Denmark', 1994, 5204994)
# (406, 'Denmark', 1995, 5227861)
# (407, 'Denmark', 1996, 5261503)
# (408, 'Denmark', 1997, 5284220)
# (409, 'Denmark', 1998, 5301304)
# (410, 'Denmark', 1999, 5319111)
# (411, 'Denmark', 2000, 5337344)
# (412, 'Denmark', 2001, 5355082)
# (413, 'Denmark', 2002, 5374255)
# (414, 'Denmark', 2003, 5387174)
# (415, 'Denmark', 2004, 5401177)
# (416, 'Denmark', 2005, 5415978)
# (417, 'Denmark', 2006, 5434567)
# (418, 'Denmark', 2007, 5457415)
# (419, 'Denmark', 2008, 5489022)
# (420, 'Denmark', 2009, 5519441)
# (421, 'Denmark', 2010, 5543819)
# (422, 'Denmark', 2011, 5566856)
# (423, 'Denmark', 2012, 5587085)
# (424, 'Denmark', 2013, 5608784)
# (425, 'Denmark', 2014, 5639719)
# (426, 'Denmark', 2015, 5678348)
# (427, 'Denmark', 2016, 5724456)
# (428, 'Denmark', 2017, 5760694)
# (429, 'Denmark', 2018, 5789957)
# (430, 'Denmark', 2019, 5814461)
# (431, 'Denmark', 2020, 5825337)
# (432, 'Denmark', 2021, 5850189)
# (433, 'Finland', 1950, 4008902)
# (434, 'Finland', 1951, 4047264)
# (435, 'Finland', 1952, 4090476)
# (436, 'Finland', 1953, 4139418)
# (437, 'Finland', 1954, 4186901)
# (438, 'Finland', 1955, 4234881)
# (439, 'Finland', 1956, 4281703)
# (440, 'Finland', 1957, 4324012)
# (441, 'Finland', 1958, 4359753)
# (442, 'Finland', 1959, 4394680)
# (443, 'Finland', 1960, 4429633)
# (444, 'Finland', 1961, 4461007)
# (445, 'Finland', 1962, 4491442)
# (446, 'Finland', 1963, 4523307)
# (447, 'Finland', 1964, 4548545)
# (448, 'Finland', 1965, 4563732)
# (449, 'Finland', 1966, 4580868)
# (450, 'Finland', 1967, 4605743)
# (451, 'Finland', 1968, 4626471)
# (452, 'Finland', 1969, 4623785)
# (453, 'Finland', 1970, 4606304)
# (454, 'Finland', 1971, 4612124)
# (455, 'Finland', 1972, 4639656)
# (456, 'Finland', 1973, 4666079)
# (457, 'Finland', 1974, 4690575)
# (458, 'Finland', 1975, 4711440)
# (459, 'Finland', 1976, 4725665)
# (460, 'Finland', 1977, 4738900)
# (461, 'Finland', 1978, 4752527)
# (462, 'Finland', 1979, 4764691)
# (463, 'Finland', 1980, 4779537)
# (464, 'Finland', 1981, 4799962)
# (465, 'Finland', 1982, 4826931)
# (466, 'Finland', 1983, 4855786)
# (467, 'Finland', 1984, 4881806)
# (468, 'Finland', 1985, 4902202)
# (469, 'Finland', 1986, 4918150)
# (470, 'Finland', 1987, 4932123)
# (471, 'Finland', 1988, 4946487)
# (472, 'Finland', 1989, 4964370)
# (473, 'Finland', 1990, 4986433)
# (474, 'Finland', 1991, 5013737)
# (475, 'Finland', 1992, 5041990)
# (476, 'Finland', 1993, 5066452)
# (477, 'Finland', 1994, 5088324)
# (478, 'Finland', 1995, 5107787)
# (479, 'Finland', 1996, 5124573)
# (480, 'Finland', 1997, 5139839)
# (481, 'Finland', 1998, 5153499)
# (482, 'Finland', 1999, 5165470)
# (483, 'Finland', 2000, 5176203)
# (484, 'Finland', 2001, 5188005)
# (485, 'Finland', 2002, 5200598)
# (486, 'Finland', 2003, 5213010)
# (487, 'Finland', 2004, 5228173)
# (488, 'Finland', 2005, 5246100)
# (489, 'Finland', 2006, 5266266)
# (490, 'Finland', 2007, 5288719)
# (491, 'Finland', 2008, 5313398)
# (492, 'Finland', 2009, 5338867)
# (493, 'Finland', 2010, 5363341)
# (494, 'Finland', 2011, 5388272)
# (495, 'Finland', 2012, 5413967)
# (496, 'Finland', 2013, 5438975)
# (497, 'Finland', 2014, 5461507)
# (498, 'Finland', 2015, 5479528)
# (499, 'Finland', 2016, 5495297)
# (500, 'Finland', 2017, 5508209)
# (501, 'Finland', 2018, 5515525)
# (502, 'Finland', 2019, 5521605)
# (503, 'Finland', 2020, 5529545)
# (504, 'Finland', 2021, 5541020)
# (505, 'France', 1950, 41828708)
# (506, 'France', 1951, 42155531)
# (507, 'France', 1952, 42459667)
# (508, 'France', 1953, 42751748)
# (509, 'France', 1954, 43056508)
# (510, 'France', 1955, 43427667)
# (511, 'France', 1956, 43843074)
# (512, 'France', 1957, 44310865)
# (513, 'France', 1958, 44788852)
# (514, 'France', 1959, 45239730)
# (515, 'France', 1960, 45684228)
# (516, 'France', 1961, 46162831)
# (517, 'France', 1962, 46997707)
# (518, 'France', 1963, 47816220)
# (519, 'France', 1964, 48310410)
# (520, 'France', 1965, 48757799)
# (521, 'France', 1966, 49163665)
# (522, 'France', 1967, 49548302)
# (523, 'France', 1968, 49915403)
# (524, 'France', 1969, 50317983)
# (525, 'France', 1970, 50772222)
# (526, 'France', 1971, 51251098)
# (527, 'France', 1972, 51700913)
# (528, 'France', 1973, 52118300)
# (529, 'France', 1974, 52460358)
# (530, 'France', 1975, 52699171)
# (531, 'France', 1976, 52908675)
# (532, 'France', 1977, 53145280)
# (533, 'France', 1978, 53376322)
# (534, 'France', 1979, 53606226)
# (535, 'France', 1980, 53880012)
# (536, 'France', 1981, 54181806)
# (537, 'France', 1982, 54492495)
# (538, 'France', 1983, 54772418)
# (539, 'France', 1984, 55026074)
# (540, 'France', 1985, 55284271)
# (541, 'France', 1986, 55546504)
# (542, 'France', 1987, 55823956)
# (543, 'France', 1988, 56117974)
# (544, 'France', 1989, 56423411)
# (545, 'France', 1990, 56708826)
# (546, 'France', 1991, 58425681)
# (547, 'France', 1992, 58711615)
# (548, 'France', 1993, 58961049)
# (549, 'France', 1994, 59175335)
# (550, 'France', 1995, 59383991)
# (551, 'France', 1996, 59589289)
# (552, 'France', 1997, 59795263)
# (553, 'France', 1998, 60011008)
# (554, 'France', 1999, 60315406)
# (555, 'France', 2000, 60724780)
# (556, 'France', 2001, 61163237)
# (557, 'France', 2002, 61604550)
# (558, 'France', 2003, 62037544)
# (559, 'France', 2004, 62490800)
# (560, 'France', 2005, 62958328)
# (561, 'France', 2006, 63393406)
# (562, 'France', 2007, 63781275)
# (563, 'France', 2008, 64133174)
# (564, 'France', 2009, 64458715)
# (565, 'France', 2010, 64773169)
# (566, 'France', 2011, 65087317)
# (567, 'France', 2012, 65402998)
# (568, 'France', 2013, 65735961)
# (569, 'France', 2014, 66276671)
# (570, 'France', 2015, 66512558)
# (571, 'France', 2016, 66688563)
# (572, 'France', 2017, 66883314)
# (573, 'France', 2018, 67125071)
# (574, 'France', 2019, 67356050)
# (575, 'France', 2020, 67540257)
# (576, 'France', 2021, 67719897)
# (577, 'Germany', 1950, 69966252)
# (578, 'Germany', 1951, 69565603)
# (579, 'Germany', 1952, 69974838)
# (580, 'Germany', 1953, 70365355)
# (581, 'Germany', 1954, 70755387)
# (582, 'Germany', 1955, 71147383)
# (583, 'Germany', 1956, 71146613)
# (584, 'Germany', 1957, 71209164)
# (585, 'Germany', 1958, 71752946)
# (586, 'Germany', 1959, 72286928)
# (587, 'Germany', 1960, 72814897)
# (588, 'Germany', 1961, 73377631)
# (589, 'Germany', 1962, 74025787)
# (590, 'Germany', 1963, 74714356)
# (591, 'Germany', 1964, 75318338)
# (592, 'Germany', 1965, 75963697)
# (593, 'Germany', 1966, 76600311)
# (594, 'Germany', 1967, 76951342)
# (595, 'Germany', 1968, 77294310)
# (596, 'Germany', 1969, 77909681)
# (597, 'Germany', 1970, 78169285)
# (598, 'Germany', 1971, 78312838)
# (599, 'Germany', 1972, 78688450)
# (600, 'Germany', 1973, 78936672)
# (601, 'Germany', 1974, 78967429)
# (602, 'Germany', 1975, 78673555)
# (603, 'Germany', 1976, 78336948)
# (604, 'Germany', 1977, 78159813)
# (605, 'Germany', 1978, 78091821)
# (606, 'Germany', 1979, 78126353)
# (607, 'Germany', 1980, 78288576)
# (608, 'Germany', 1981, 78407904)
# (609, 'Germany', 1982, 78333354)
# (610, 'Germany', 1983, 78128284)
# (611, 'Germany', 1984, 77858682)
# (612, 'Germany', 1985, 77684878)
# (613, 'Germany', 1986, 77720438)
# (614, 'Germany', 1987, 77839920)
# (615, 'Germany', 1988, 78144617)
# (616, 'Germany', 1989, 78751284)
# (617, 'Germany', 1990, 79433034)
# (618, 'Germany', 1991, 80013901)
# (619, 'Germany', 1992, 80624601)
# (620, 'Germany', 1993, 81156368)
# (621, 'Germany', 1994, 81438346)
# (622, 'Germany', 1995, 81678046)
# (623, 'Germany', 1996, 81914834)
# (624, 'Germany', 1997, 82034775)
# (625, 'Germany', 1998, 82047197)
# (626, 'Germany', 1999, 82100243)
# (627, 'Germany', 2000, 82211501)
# (628, 'Germany', 2001, 82349926)
# (629, 'Germany', 2002, 82488493)
# (630, 'Germany', 2003, 82534175)
# (631, 'Germany', 2004, 82516268)
# (632, 'Germany', 2005, 82469421)
# (633, 'Germany', 2006, 82376447)
# (634, 'Germany', 2007, 82266373)
# (635, 'Germany', 2008, 82110097)
# (636, 'Germany', 2009, 81902308)
# (637, 'Germany', 2010, 81776936)
# (638, 'Germany', 2011, 80274981)
# (639, 'Germany', 2012, 80425826)
# (640, 'Germany', 2013, 80645605)
# (641, 'Germany', 2014, 80982495)
# (642, 'Germany', 2015, 81686608)
# (643, 'Germany', 2016, 82348669)
# (644, 'Germany', 2017, 82657000)
# (645, 'Germany', 2018, 82905788)
# (646, 'Germany', 2019, 83092958)
# (647, 'Germany', 2020, 83160874)
# (648, 'Germany', 2021, 83129285)
# (649, 'Greece', 1950, 7554102)
# (650, 'Greece', 1951, 7632801)
# (651, 'Greece', 1952, 7743746)
# (652, 'Greece', 1953, 7836110)
# (653, 'Greece', 1954, 7893412)
# (654, 'Greece', 1955, 7965538)
# (655, 'Greece', 1956, 8031013)
# (656, 'Greece', 1957, 8096218)
# (657, 'Greece', 1958, 8173129)
# (658, 'Greece', 1959, 8258162)
# (659, 'Greece', 1960, 8327405)
# (660, 'Greece', 1961, 8398050)
# (661, 'Greece', 1962, 8448233)
# (662, 'Greece', 1963, 8479625)
# (663, 'Greece', 1964, 8510429)
# (664, 'Greece', 1965, 8550333)
# (665, 'Greece', 1966, 8613651)
# (666, 'Greece', 1967, 8716441)
# (667, 'Greece', 1968, 8740765)
# (668, 'Greece', 1969, 8772764)
# (669, 'Greece', 1970, 8792806)
# (670, 'Greece', 1971, 8831036)
# (671, 'Greece', 1972, 8888628)
# (672, 'Greece', 1973, 8929086)
# (673, 'Greece', 1974, 8962023)
# (674, 'Greece', 1975, 9046542)
# (675, 'Greece', 1976, 9167190)
# (676, 'Greece', 1977, 9308479)
# (677, 'Greece', 1978, 9429959)
# (678, 'Greece', 1979, 9548258)
# (679, 'Greece', 1980, 9642505)
# (680, 'Greece', 1981, 9729350)
# (681, 'Greece', 1982, 9789513)
# (682, 'Greece', 1983, 9846627)
# (683, 'Greece', 1984, 9895801)
# (684, 'Greece', 1985, 9934294)
# (685, 'Greece', 1986, 9967264)
# (686, 'Greece', 1987, 10000644)
# (687, 'Greece', 1988, 10037037)
# (688, 'Greece', 1989, 10089550)
# (689, 'Greece', 1990, 10196801)
# (690, 'Greece', 1991, 10319928)
# (691, 'Greece', 1992, 10399058)
# (692, 'Greece', 1993, 10460409)
# (693, 'Greece', 1994, 10512924)
# (694, 'Greece', 1995, 10562160)
# (695, 'Greece', 1996, 10608801)
# (696, 'Greece', 1997, 10661264)
# (697, 'Greece', 1998, 10720507)
# (698, 'Greece', 1999, 10761698)
# (699, 'Greece', 2000, 10805806)
# (700, 'Greece', 2001, 10862129)
# (701, 'Greece', 2002, 10902022)
# (702, 'Greece', 2003, 10928072)
# (703, 'Greece', 2004, 10955142)
# (704, 'Greece', 2005, 10987316)
# (705, 'Greece', 2006, 11020366)
# (706, 'Greece', 2007, 11048466)
# (707, 'Greece', 2008, 11077839)
# (708, 'Greece', 2009, 11107017)
# (709, 'Greece', 2010, 11121344)
# (710, 'Greece', 2011, 11104900)
# (711, 'Greece', 2012, 11045010)
# (712, 'Greece', 2013, 10965209)
# (713, 'Greece', 2014, 10892415)
# (714, 'Greece', 2015, 10820883)
# (715, 'Greece', 2016, 10775966)
# (716, 'Greece', 2017, 10754679)
# (717, 'Greece', 2018, 10732877)
# (718, 'Greece', 2019, 10721584)
# (719, 'Greece', 2020, 10698597)
# (720, 'Greece', 2021, 10656962)
# (721, 'Hungary', 1950, 9337770)
# (722, 'Hungary', 1951, 9422958)
# (723, 'Hungary', 1952, 9504043)
# (724, 'Hungary', 1953, 9595144)
# (725, 'Hungary', 1954, 9705833)
# (726, 'Hungary', 1955, 9824908)
# (727, 'Hungary', 1956, 9855888)
# (728, 'Hungary', 1957, 9839364)
# (729, 'Hungary', 1958, 9881594)
# (730, 'Hungary', 1959, 9937033)
# (731, 'Hungary', 1960, 9983514)
# (732, 'Hungary', 1961, 10027958)
# (733, 'Hungary', 1962, 10060823)
# (734, 'Hungary', 1963, 10087948)
# (735, 'Hungary', 1964, 10119834)
# (736, 'Hungary', 1965, 10147932)
# (737, 'Hungary', 1966, 10178653)
# (738, 'Hungary', 1967, 10216607)
# (739, 'Hungary', 1968, 10255807)
# (740, 'Hungary', 1969, 10298722)
# (741, 'Hungary', 1970, 10337912)
# (742, 'Hungary', 1971, 10367535)
# (743, 'Hungary', 1972, 10398491)
# (744, 'Hungary', 1973, 10432053)
# (745, 'Hungary', 1974, 10478720)
# (746, 'Hungary', 1975, 10540523)
# (747, 'Hungary', 1976, 10598674)
# (748, 'Hungary', 1977, 10648028)
# (749, 'Hungary', 1978, 10684829)
# (750, 'Hungary', 1979, 10704148)
# (751, 'Hungary', 1980, 10711126)
# (752, 'Hungary', 1981, 10711853)
# (753, 'Hungary', 1982, 10705537)
# (754, 'Hungary', 1983, 10689467)
# (755, 'Hungary', 1984, 10668092)
# (756, 'Hungary', 1985, 10648715)
# (757, 'Hungary', 1986, 10630565)
# (758, 'Hungary', 1987, 10612743)
# (759, 'Hungary', 1988, 10596489)
# (760, 'Hungary', 1989, 10481717)
# (761, 'Hungary', 1990, 10373987)
# (762, 'Hungary', 1991, 10373398)
# (763, 'Hungary', 1992, 10369339)
# (764, 'Hungary', 1993, 10357518)
# (765, 'Hungary', 1994, 10343359)
# (766, 'Hungary', 1995, 10328967)
# (767, 'Hungary', 1996, 10311235)
# (768, 'Hungary', 1997, 10290475)
# (769, 'Hungary', 1998, 10266571)
# (770, 'Hungary', 1999, 10237527)
# (771, 'Hungary', 2000, 10210965)
# (772, 'Hungary', 2001, 10187578)
# (773, 'Hungary', 2002, 10158610)
# (774, 'Hungary', 2003, 10129554)
# (775, 'Hungary', 2004, 10107140)
# (776, 'Hungary', 2005, 10087064)
# (777, 'Hungary', 2006, 10071374)
# (778, 'Hungary', 2007, 10055778)
# (779, 'Hungary', 2008, 10038186)
# (780, 'Hungary', 2009, 10022647)
# (781, 'Hungary', 2010, 10000020)
# (782, 'Hungary', 2011, 9958824)
# (783, 'Hungary', 2012, 9920364)
# (784, 'Hungary', 2013, 9893083)
# (785, 'Hungary', 2014, 9866466)
# (786, 'Hungary', 2015, 9843025)
# (787, 'Hungary', 2016, 9814026)
# (788, 'Hungary', 2017, 9787969)
# (789, 'Hungary', 2018, 9775566)
# (790, 'Hungary', 2019, 9771142)
# (791, 'Hungary', 2020, 9750153)
# (792, 'Hungary', 2021, 9710107)
# (793, 'Iceland', 1950, 142660)
# (794, 'Iceland', 1951, 145417)
# (795, 'Iceland', 1952, 147762)
# (796, 'Iceland', 1953, 150746)
# (797, 'Iceland', 1954, 154272)
# (798, 'Iceland', 1955, 157759)
# (799, 'Iceland', 1956, 161097)
# (800, 'Iceland', 1957, 164766)
# (801, 'Iceland', 1958, 168490)
# (802, 'Iceland', 1959, 172013)
# (803, 'Iceland', 1960, 175573)
# (804, 'Iceland', 1961, 179028)
# (805, 'Iceland', 1962, 182376)
# (806, 'Iceland', 1963, 185648)
# (807, 'Iceland', 1964, 188983)
# (808, 'Iceland', 1965, 192285)
# (809, 'Iceland', 1966, 195568)
# (810, 'Iceland', 1967, 198757)
# (811, 'Iceland', 1968, 201487)
# (812, 'Iceland', 1969, 203370)
# (813, 'Iceland', 1970, 204438)
# (814, 'Iceland', 1971, 206099)
# (815, 'Iceland', 1972, 209137)
# (816, 'Iceland', 1973, 212316)
# (817, 'Iceland', 1974, 215206)
# (818, 'Iceland', 1975, 217974)
# (819, 'Iceland', 1976, 220151)
# (820, 'Iceland', 1977, 221801)
# (821, 'Iceland', 1978, 223537)
# (822, 'Iceland', 1979, 225734)
# (823, 'Iceland', 1980, 228133)
# (824, 'Iceland', 1981, 230757)
# (825, 'Iceland', 1982, 233855)
# (826, 'Iceland', 1983, 236976)
# (827, 'Iceland', 1984, 239506)
# (828, 'Iceland', 1985, 241409)
# (829, 'Iceland', 1986, 243187)
# (830, 'Iceland', 1987, 245864)
# (831, 'Iceland', 1988, 249734)
# (832, 'Iceland', 1989, 252851)
# (833, 'Iceland', 1990, 254820)
# (834, 'Iceland', 1991, 257795)
# (835, 'Iceland', 1992, 261053)
# (836, 'Iceland', 1993, 263730)
# (837, 'Iceland', 1994, 266021)
# (838, 'Iceland', 1995, 267467)
# (839, 'Iceland', 1996, 268918)
# (840, 'Iceland', 1997, 271130)
# (841, 'Iceland', 1998, 274049)
# (842, 'Iceland', 1999, 277384)
# (843, 'Iceland', 2000, 281200)
# (844, 'Iceland', 2001, 284970)
# (845, 'Iceland', 2002, 287516)
# (846, 'Iceland', 2003, 289522)
# (847, 'Iceland', 2004, 292077)
# (848, 'Iceland', 2005, 296734)
# (849, 'Iceland', 2006, 303784)
# (850, 'Iceland', 2007, 311567)
# (851, 'Iceland', 2008, 317404)
# (852, 'Iceland', 2009, 318501)
# (853, 'Iceland', 2010, 318044)
# (854, 'Iceland', 2011, 319011)
# (855, 'Iceland', 2012, 320723)
# (856, 'Iceland', 2013, 323763)
# (857, 'Iceland', 2014, 327379)
# (858, 'Iceland', 2015, 330818)
# (859, 'Iceland', 2016, 335435)
# (860, 'Iceland', 2017, 343399)
# (861, 'Iceland', 2018, 352722)
# (862, 'Iceland', 2019, 360558)
# (863, 'Iceland', 2020, 366462)
# (864, 'Iceland', 2021, 372523)
# (865, 'Ireland', 1950, 2969000)
# (866, 'Ireland', 1951, 2960600)
# (867, 'Ireland', 1952, 2952900)
# (868, 'Ireland', 1953, 2949000)
# (869, 'Ireland', 1954, 2941200)
# (870, 'Ireland', 1955, 2920900)
# (871, 'Ireland', 1956, 2898500)
# (872, 'Ireland', 1957, 2885300)
# (873, 'Ireland', 1958, 2852700)
# (874, 'Ireland', 1959, 2845600)
# (875, 'Ireland', 1960, 2832100)
# (876, 'Ireland', 1961, 2818300)
# (877, 'Ireland', 1962, 2830100)
# (878, 'Ireland', 1963, 2850000)
# (879, 'Ireland', 1964, 2863800)
# (880, 'Ireland', 1965, 2875800)
# (881, 'Ireland', 1966, 2884000)
# (882, 'Ireland', 1967, 2899700)
# (883, 'Ireland', 1968, 2912200)
# (884, 'Ireland', 1969, 2925200)
# (885, 'Ireland', 1970, 2949900)
# (886, 'Ireland', 1971, 2978200)
# (887, 'Ireland', 1972, 3024400)
# (888, 'Ireland', 1973, 3073000)
# (889, 'Ireland', 1974, 3123900)
# (890, 'Ireland', 1975, 3177200)
# (891, 'Ireland', 1976, 3227800)
# (892, 'Ireland', 1977, 3271900)
# (893, 'Ireland', 1978, 3314000)
# (894, 'Ireland', 1979, 3368200)
# (895, 'Ireland', 1980, 3401000)
# (896, 'Ireland', 1981, 3443400)
# (897, 'Ireland', 1982, 3480000)
# (898, 'Ireland', 1983, 3504000)
# (899, 'Ireland', 1984, 3529000)
# (900, 'Ireland', 1985, 3540000)
# (901, 'Ireland', 1986, 3540600)
# (902, 'Ireland', 1987, 3546500)
# (903, 'Ireland', 1988, 3530700)
# (904, 'Ireland', 1989, 3509500)
# (905, 'Ireland', 1990, 3505800)
# (906, 'Ireland', 1991, 3525700)
# (907, 'Ireland', 1992, 3554500)
# (908, 'Ireland', 1993, 3574100)
# (909, 'Ireland', 1994, 3585900)
# (910, 'Ireland', 1995, 3601300)
# (911, 'Ireland', 1996, 3626087)
# (912, 'Ireland', 1997, 3664313)
# (913, 'Ireland', 1998, 3703082)
# (914, 'Ireland', 1999, 3741647)
# (915, 'Ireland', 2000, 3789536)
# (916, 'Ireland', 2001, 3847198)
# (917, 'Ireland', 2002, 3917203)
# (918, 'Ireland', 2003, 3979853)
# (919, 'Ireland', 2004, 4045188)
# (920, 'Ireland', 2005, 4133839)
# (921, 'Ireland', 2006, 4232929)
# (922, 'Ireland', 2007, 4375842)
# (923, 'Ireland', 2008, 4485070)
# (924, 'Ireland', 2009, 4533395)
# (925, 'Ireland', 2010, 4554763)
# (926, 'Ireland', 2011, 4574888)
# (927, 'Ireland', 2012, 4593697)
# (928, 'Ireland', 2013, 4614669)
# (929, 'Ireland', 2014, 4645440)
# (930, 'Ireland', 2015, 4687787)
# (931, 'Ireland', 2016, 4739597)
# (932, 'Ireland', 2017, 4792490)
# (933, 'Ireland', 2018, 4857015)
# (934, 'Ireland', 2019, 4921496)
# (935, 'Ireland', 2020, 4977443)
# (936, 'Ireland', 2021, 5011460)
# (937, 'Italy', 1950, 47104001)
# (938, 'Italy', 1951, 47407195)
# (939, 'Italy', 1952, 47665530)
# (940, 'Italy', 1953, 47957348)
# (941, 'Italy', 1954, 48299578)
# (942, 'Italy', 1955, 48632556)
# (943, 'Italy', 1956, 48921093)
# (944, 'Italy', 1957, 49183204)
# (945, 'Italy', 1958, 49476429)
# (946, 'Italy', 1959, 49832779)
# (947, 'Italy', 1960, 50199634)
# (948, 'Italy', 1961, 50536309)
# (949, 'Italy', 1962, 50879432)
# (950, 'Italy', 1963, 51251937)
# (951, 'Italy', 1964, 51675294)
# (952, 'Italy', 1965, 52112336)
# (953, 'Italy', 1966, 52518925)
# (954, 'Italy', 1967, 52900443)
# (955, 'Italy', 1968, 53235691)
# (956, 'Italy', 1969, 53537796)
# (957, 'Italy', 1970, 53821798)
# (958, 'Italy', 1971, 54073525)
# (959, 'Italy', 1972, 54381345)
# (960, 'Italy', 1973, 54751405)
# (961, 'Italy', 1974, 55110870)
# (962, 'Italy', 1975, 55440999)
# (963, 'Italy', 1976, 55718266)
# (964, 'Italy', 1977, 55955407)
# (965, 'Italy', 1978, 56155142)
# (966, 'Italy', 1979, 56317750)
# (967, 'Italy', 1980, 56433876)
# (968, 'Italy', 1981, 56501674)
# (969, 'Italy', 1982, 56543539)
# (970, 'Italy', 1983, 56564076)
# (971, 'Italy', 1984, 56576719)
# (972, 'Italy', 1985, 56593070)
# (973, 'Italy', 1986, 56596157)
# (974, 'Italy', 1987, 56601936)
# (975, 'Italy', 1988, 56629290)
# (976, 'Italy', 1989, 56671778)
# (977, 'Italy', 1990, 56719239)
# (978, 'Italy', 1991, 56758522)
# (979, 'Italy', 1992, 56797078)
# (980, 'Italy', 1993, 56831823)
# (981, 'Italy', 1994, 56843400)
# (982, 'Italy', 1995, 56844301)
# (983, 'Italy', 1996, 56860279)
# (984, 'Italy', 1997, 56890371)
# (985, 'Italy', 1998, 56906744)
# (986, 'Italy', 1999, 56916316)
# (987, 'Italy', 2000, 56942108)
# (988, 'Italy', 2001, 56976976)
# (989, 'Italy', 2002, 57089823)
# (990, 'Italy', 2003, 57399187)
# (991, 'Italy', 2004, 57828178)
# (992, 'Italy', 2005, 58166684)
# (993, 'Italy', 2006, 58399863)
# (994, 'Italy', 2007, 58756247)
# (995, 'Italy', 2008, 59211183)
# (996, 'Italy', 2009, 59555456)
# (997, 'Italy', 2010, 59819402)
# (998, 'Italy', 2011, 60026844)
# (999, 'Italy', 2012, 60191243)
# (1000, 'Italy', 2013, 60311616)
# (1001, 'Italy', 2014, 60320708)
# (1002, 'Italy', 2015, 60229599)
# (1003, 'Italy', 2016, 60115220)
# (1004, 'Italy', 2017, 60002254)
# (1005, 'Italy', 2018, 59877216)
# (1006, 'Italy', 2019, 59729077)
# (1007, 'Italy', 2020, 59438845)
# (1008, 'Italy', 2021, 59109666)
# (1009, 'Japan', 1950, 84109139)
# (1010, 'Japan', 1951, 85475000)
# (1011, 'Japan', 1952, 86765900)
# (1012, 'Japan', 1953, 87955300)
# (1013, 'Japan', 1954, 89026700)
# (1014, 'Japan', 1955, 90076594)
# (1015, 'Japan', 1956, 90992000)
# (1016, 'Japan', 1957, 91763000)
# (1017, 'Japan', 1958, 92621000)
# (1018, 'Japan', 1959, 93514000)
# (1019, 'Japan', 1960, 94301623)
# (1020, 'Japan', 1961, 95181000)
# (1021, 'Japan', 1962, 96087000)
# (1022, 'Japan', 1963, 97075000)
# (1023, 'Japan', 1964, 98110000)
# (1024, 'Japan', 1965, 99209137)
# (1025, 'Japan', 1966, 99978000)
# (1026, 'Japan', 1967, 101145000)
# (1027, 'Japan', 1968, 102287000)
# (1028, 'Japan', 1969, 103491000)
# (1029, 'Japan', 1970, 104665171)
# (1030, 'Japan', 1971, 106100000)
# (1031, 'Japan', 1972, 107595000)
# (1032, 'Japan', 1973, 109104000)
# (1033, 'Japan', 1974, 110573000)
# (1034, 'Japan', 1975, 111939643)
# (1035, 'Japan', 1976, 113094000)
# (1036, 'Japan', 1977, 114165000)
# (1037, 'Japan', 1978, 115190000)
# (1038, 'Japan', 1979, 116155000)
# (1039, 'Japan', 1980, 117060396)
# (1040, 'Japan', 1981, 117902000)
# (1041, 'Japan', 1982, 118728000)
# (1042, 'Japan', 1983, 119536000)
# (1043, 'Japan', 1984, 120305000)
# (1044, 'Japan', 1985, 121048923)
# (1045, 'Japan', 1986, 121660000)
# (1046, 'Japan', 1987, 122239000)
# (1047, 'Japan', 1988, 122745000)
# (1048, 'Japan', 1989, 123205000)
# (1049, 'Japan', 1990, 123611167)
# (1050, 'Japan', 1991, 124101000)
# (1051, 'Japan', 1992, 124567000)
# (1052, 'Japan', 1993, 124938000)
# (1053, 'Japan', 1994, 125265000)
# (1054, 'Japan', 1995, 125570246)
# (1055, 'Japan', 1996, 125864000)
# (1056, 'Japan', 1997, 126166000)
# (1057, 'Japan', 1998, 126486000)
# (1058, 'Japan', 1999, 126686000)
# (1059, 'Japan', 2000, 126925843)
# (1060, 'Japan', 2001, 127291000)
# (1061, 'Japan', 2002, 127435000)
# (1062, 'Japan', 2003, 127619000)
# (1063, 'Japan', 2004, 127687000)
# (1064, 'Japan', 2005, 127767994)
# (1065, 'Japan', 2006, 127900515)
# (1066, 'Japan', 2007, 128032743)
# (1067, 'Japan', 2008, 128083960)
# (1068, 'Japan', 2009, 128031514)
# (1069, 'Japan', 2010, 128057352)
# (1070, 'Japan', 2011, 127834233)
# (1071, 'Japan', 2012, 127592657)
# (1072, 'Japan', 2013, 127413888)
# (1073, 'Japan', 2014, 127237150)
# (1074, 'Japan', 2015, 127094745)
# (1075, 'Japan', 2016, 126932772)
# (1076, 'Japan', 2017, 126706210)
# (1077, 'Japan', 2018, 126443180)
# (1078, 'Japan', 2019, 126166948)
# (1079, 'Japan', 2020, 126146099)
# (1080, 'Japan', 2021, 125502290)
# (1153, 'Luxembourg', 1950, 296005)
# (1154, 'Luxembourg', 1951, 297593)
# (1155, 'Luxembourg', 1952, 299500)
# (1156, 'Luxembourg', 1953, 301507)
# (1157, 'Luxembourg', 1954, 303449)
# (1158, 'Luxembourg', 1955, 305262)
# (1159, 'Luxembourg', 1956, 306938)
# (1160, 'Luxembourg', 1957, 308562)
# (1161, 'Luxembourg', 1958, 310258)
# (1162, 'Luxembourg', 1959, 312219)
# (1163, 'Luxembourg', 1960, 314585)
# (1164, 'Luxembourg', 1961, 317438)
# (1165, 'Luxembourg', 1962, 320699)
# (1166, 'Luxembourg', 1963, 324129)
# (1167, 'Luxembourg', 1964, 327360)
# (1168, 'Luxembourg', 1965, 330160)
# (1169, 'Luxembourg', 1966, 332423)
# (1170, 'Luxembourg', 1967, 334234)
# (1171, 'Luxembourg', 1968, 335829)
# (1172, 'Luxembourg', 1969, 337568)
# (1173, 'Luxembourg', 1970, 339174)
# (1174, 'Luxembourg', 1971, 342415)
# (1175, 'Luxembourg', 1972, 346600)
# (1176, 'Luxembourg', 1973, 350450)
# (1177, 'Luxembourg', 1974, 355049)
# (1178, 'Luxembourg', 1975, 358951)
# (1179, 'Luxembourg', 1976, 360728)
# (1180, 'Luxembourg', 1977, 361356)
# (1181, 'Luxembourg', 1978, 362010)
# (1182, 'Luxembourg', 1979, 362856)
# (1183, 'Luxembourg', 1980, 364152)
# (1184, 'Luxembourg', 1981, 365219)
# (1185, 'Luxembourg', 1982, 365525)
# (1186, 'Luxembourg', 1983, 365621)
# (1187, 'Luxembourg', 1984, 365997)
# (1188, 'Luxembourg', 1985, 366707)
# (1189, 'Luxembourg', 1986, 368354)
# (1190, 'Luxembourg', 1987, 370751)
# (1191, 'Luxembourg', 1988, 373450)
# (1192, 'Luxembourg', 1989, 377095)
# (1193, 'Luxembourg', 1990, 381857)
# (1194, 'Luxembourg', 1991, 386999)
# (1195, 'Luxembourg', 1992, 392171)
# (1196, 'Luxembourg', 1993, 397481)
# (1197, 'Luxembourg', 1994, 402921)
# (1198, 'Luxembourg', 1995, 408625)
# (1199, 'Luxembourg', 1996, 414228)
# (1200, 'Luxembourg', 1997, 419440)
# (1201, 'Luxembourg', 1998, 424699)
# (1202, 'Luxembourg', 1999, 430475)
# (1203, 'Luxembourg', 2000, 436303)
# (1204, 'Luxembourg', 2001, 441522)
# (1205, 'Luxembourg', 2002, 446166)
# (1206, 'Luxembourg', 2003, 451626)
# (1207, 'Luxembourg', 2004, 458098)
# (1208, 'Luxembourg', 2005, 465152)
# (1209, 'Luxembourg', 2006, 472641)
# (1210, 'Luxembourg', 2007, 479992)
# (1211, 'Luxembourg', 2008, 488647)
# (1212, 'Luxembourg', 2009, 497783)
# (1213, 'Luxembourg', 2010, 506953)
# (1214, 'Luxembourg', 2011, 518351)
# (1215, 'Luxembourg', 2012, 530952)
# (1216, 'Luxembourg', 2013, 543358)
# (1217, 'Luxembourg', 2014, 556322)
# (1218, 'Luxembourg', 2015, 569605)
# (1219, 'Luxembourg', 2016, 583459)
# (1220, 'Luxembourg', 2017, 596337)
# (1221, 'Luxembourg', 2018, 607950)
# (1222, 'Luxembourg', 2019, 620003)
# (1223, 'Luxembourg', 2020, 630413)
# (1224, 'Luxembourg', 2021, 640064)
# (1225, 'Mexico', 1950, 27026573)
# (1226, 'Mexico', 1951, 27780135)
# (1227, 'Mexico', 1952, 28578641)
# (1228, 'Mexico', 1953, 29418995)
# (1229, 'Mexico', 1954, 30311877)
# (1230, 'Mexico', 1955, 31272636)
# (1231, 'Mexico', 1956, 32281478)
# (1232, 'Mexico', 1957, 33337148)
# (1233, 'Mexico', 1958, 34439604)
# (1234, 'Mexico', 1959, 35591229)
# (1235, 'Mexico', 1960, 36786543)
# (1236, 'Mexico', 1961, 38025871)
# (1237, 'Mexico', 1962, 39306372)
# (1238, 'Mexico', 1963, 40619346)
# (1239, 'Mexico', 1964, 41970377)
# (1240, 'Mexico', 1965, 43359231)
# (1241, 'Mexico', 1966, 44779078)
# (1242, 'Mexico', 1967, 46234469)
# (1243, 'Mexico', 1968, 47720198)
# (1244, 'Mexico', 1969, 49236362)
# (1245, 'Mexico', 1970, 50778729)
# (1246, 'Mexico', 1971, 52354238)
# (1247, 'Mexico', 1972, 53973953)
# (1248, 'Mexico', 1973, 55619995)
# (1249, 'Mexico', 1974, 57293865)
# (1250, 'Mexico', 1975, 58993234)
# (1251, 'Mexico', 1976, 60702805)
# (1252, 'Mexico', 1977, 62414539)
# (1253, 'Mexico', 1978, 64131336)
# (1254, 'Mexico', 1979, 65849531)
# (1255, 'Mexico', 1980, 67561216)
# (1256, 'Mexico', 1981, 69267849)
# (1257, 'Mexico', 1982, 70973052)
# (1258, 'Mexico', 1983, 72671675)
# (1259, 'Mexico', 1984, 74359027)
# (1260, 'Mexico', 1985, 76030535)
# (1261, 'Mexico', 1986, 77689757)
# (1262, 'Mexico', 1987, 79339498)
# (1263, 'Mexico', 1988, 80970606)
# (1264, 'Mexico', 1989, 82579032)
# (1265, 'Mexico', 1990, 84169571)
# (1266, 'Mexico', 1991, 85748742)
# (1267, 'Mexico', 1992, 87312337)
# (1268, 'Mexico', 1993, 88850856)
# (1269, 'Mexico', 1994, 90362709)
# (1270, 'Mexico', 1995, 91843905)
# (1271, 'Mexico', 1996, 93294783)
# (1272, 'Mexico', 1997, 94720541)
# (1273, 'Mexico', 1998, 96116960)
# (1274, 'Mexico', 1999, 97482584)
# (1275, 'Mexico', 2000, 98785275)
# (1276, 'Mexico', 2001, 100105299)
# (1277, 'Mexico', 2002, 101493987)
# (1278, 'Mexico', 2003, 102890474)
# (1279, 'Mexico', 2004, 104272444)
# (1280, 'Mexico', 2005, 105669369)
# (1281, 'Mexico', 2006, 107155391)
# (1282, 'Mexico', 2007, 108744845)
# (1283, 'Mexico', 2008, 110405454)
# (1284, 'Mexico', 2009, 112095388)
# (1285, 'Mexico', 2010, 113748671)
# (1286, 'Mexico', 2011, 115367452)
# (1287, 'Mexico', 2012, 116935670)
# (1288, 'Mexico', 2013, 118453929)
# (1289, 'Mexico', 2014, 119936411)
# (1290, 'Mexico', 2015, 121347800)
# (1291, 'Mexico', 2016, 122715165)
# (1292, 'Mexico', 2017, 124041731)
# (1293, 'Mexico', 2018, 125327797)
# (1294, 'Mexico', 2019, 126577691)
# (1295, 'Mexico', 2020, 127792286)
# (1296, 'Mexico', 2021, 128972439)
# (1297, 'Netherlands', 1950, 10113528)
# (1298, 'Netherlands', 1951, 10264309)
# (1299, 'Netherlands', 1952, 10381980)
# (1300, 'Netherlands', 1953, 10493184)
# (1301, 'Netherlands', 1954, 10615385)
# (1302, 'Netherlands', 1955, 10750840)
# (1303, 'Netherlands', 1956, 10889358)
# (1304, 'Netherlands', 1957, 11026384)
# (1305, 'Netherlands', 1958, 11186878)
# (1306, 'Netherlands', 1959, 11347635)
# (1307, 'Netherlands', 1960, 11486630)
# (1308, 'Netherlands', 1961, 11638709)
# (1309, 'Netherlands', 1962, 11805690)
# (1310, 'Netherlands', 1963, 11965967)
# (1311, 'Netherlands', 1964, 12127116)
# (1312, 'Netherlands', 1965, 12294732)
# (1313, 'Netherlands', 1966, 12456254)
# (1314, 'Netherlands', 1967, 12598202)
# (1315, 'Netherlands', 1968, 12729717)
# (1316, 'Netherlands', 1969, 12877984)
# (1317, 'Netherlands', 1970, 13038523)
# (1318, 'Netherlands', 1971, 13194497)
# (1319, 'Netherlands', 1972, 13328595)
# (1320, 'Netherlands', 1973, 13439325)
# (1321, 'Netherlands', 1974, 13545054)
# (1322, 'Netherlands', 1975, 13666329)
# (1323, 'Netherlands', 1976, 13774037)
# (1324, 'Netherlands', 1977, 13856188)
# (1325, 'Netherlands', 1978, 13941702)
# (1326, 'Netherlands', 1979, 14038270)
# (1327, 'Netherlands', 1980, 14149799)
# (1328, 'Netherlands', 1981, 14247217)
# (1329, 'Netherlands', 1982, 14312689)
# (1330, 'Netherlands', 1983, 14367066)
# (1331, 'Netherlands', 1984, 14424211)
# (1332, 'Netherlands', 1985, 14491629)
# (1333, 'Netherlands', 1986, 14572280)
# (1334, 'Netherlands', 1987, 14665037)
# (1335, 'Netherlands', 1988, 14760092)
# (1336, 'Netherlands', 1989, 14848906)
# (1337, 'Netherlands', 1990, 14951510)
# (1338, 'Netherlands', 1991, 15069799)
# (1339, 'Netherlands', 1992, 15184163)
# (1340, 'Netherlands', 1993, 15290368)
# (1341, 'Netherlands', 1994, 15382834)
# (1342, 'Netherlands', 1995, 15459004)
# (1343, 'Netherlands', 1996, 15530500)
# (1344, 'Netherlands', 1997, 15610650)
# (1345, 'Netherlands', 1998, 15707205)
# (1346, 'Netherlands', 1999, 15812085)
# (1347, 'Netherlands', 2000, 15925505)
# (1348, 'Netherlands', 2001, 16046182)
# (1349, 'Netherlands', 2002, 16148921)
# (1350, 'Netherlands', 2003, 16225303)
# (1351, 'Netherlands', 2004, 16281777)
# (1352, 'Netherlands', 2005, 16319871)
# (1353, 'Netherlands', 2006, 16346096)
# (1354, 'Netherlands', 2007, 16381696)
# (1355, 'Netherlands', 2008, 16445590)
# (1356, 'Netherlands', 2009, 16530387)
# (1357, 'Netherlands', 2010, 16615390)
# (1358, 'Netherlands', 2011, 16693074)
# (1359, 'Netherlands', 2012, 16754963)
# (1360, 'Netherlands', 2013, 16804430)
# (1361, 'Netherlands', 2014, 16865008)
# (1362, 'Netherlands', 2015, 16939925)
# (1363, 'Netherlands', 2016, 17030314)
# (1364, 'Netherlands', 2017, 17131295)
# (1365, 'Netherlands', 2018, 17231622)
# (1366, 'Netherlands', 2019, 17344876)
# (1367, 'Netherlands', 2020, 17441500)
# (1368, 'Netherlands', 2021, 17533406)
# (1369, 'New Zealand', 1950, 1909835)
# (1370, 'New Zealand', 1951, 1949185)
# (1371, 'New Zealand', 1952, 1997720)
# (1372, 'New Zealand', 1953, 2049740)
# (1373, 'New Zealand', 1954, 2096610)
# (1374, 'New Zealand', 1955, 2141610)
# (1375, 'New Zealand', 1956, 2187055)
# (1376, 'New Zealand', 1957, 2236105)
# (1377, 'New Zealand', 1958, 2289440)
# (1378, 'New Zealand', 1959, 2337880)
# (1379, 'New Zealand', 1960, 2381670)
# (1380, 'New Zealand', 1961, 2432380)
# (1381, 'New Zealand', 1962, 2488530)
# (1382, 'New Zealand', 1963, 2541415)
# (1383, 'New Zealand', 1964, 2591965)
# (1384, 'New Zealand', 1965, 2640400)
# (1385, 'New Zealand', 1966, 2687580)
# (1386, 'New Zealand', 1967, 2728115)
# (1387, 'New Zealand', 1968, 2758885)
# (1388, 'New Zealand', 1969, 2788435)
# (1389, 'New Zealand', 1970, 2828020)
# (1390, 'New Zealand', 1971, 2875305)
# (1391, 'New Zealand', 1972, 2929135)
# (1392, 'New Zealand', 1973, 2992335)
# (1393, 'New Zealand', 1974, 3058435)
# (1394, 'New Zealand', 1975, 3117765)
# (1395, 'New Zealand', 1976, 3153535)
# (1396, 'New Zealand', 1977, 3164830)
# (1397, 'New Zealand', 1978, 3165705)
# (1398, 'New Zealand', 1979, 3164620)
# (1399, 'New Zealand', 1980, 3170245)
# (1400, 'New Zealand', 1981, 3185460)
# (1401, 'New Zealand', 1982, 3210645)
# (1402, 'New Zealand', 1983, 3245770)
# (1403, 'New Zealand', 1984, 3278850)
# (1404, 'New Zealand', 1985, 3298050)
# (1405, 'New Zealand', 1986, 3308310)
# (1406, 'New Zealand', 1987, 3327785)
# (1407, 'New Zealand', 1988, 3343680)
# (1408, 'New Zealand', 1989, 3357535)
# (1409, 'New Zealand', 1990, 3390085)
# (1410, 'New Zealand', 1991, 3495100)
# (1411, 'New Zealand', 1992, 3531700)
# (1412, 'New Zealand', 1993, 3572200)
# (1413, 'New Zealand', 1994, 3620100)
# (1414, 'New Zealand', 1995, 3673400)
# (1415, 'New Zealand', 1996, 3732000)
# (1416, 'New Zealand', 1997, 3781300)
# (1417, 'New Zealand', 1998, 3815000)
# (1418, 'New Zealand', 1999, 3835100)
# (1419, 'New Zealand', 2000, 3857700)
# (1420, 'New Zealand', 2001, 3880500)
# (1421, 'New Zealand', 2002, 3948500)
# (1422, 'New Zealand', 2003, 4027200)
# (1423, 'New Zealand', 2004, 4087500)
# (1424, 'New Zealand', 2005, 4133900)
# (1425, 'New Zealand', 2006, 4184600)
# (1426, 'New Zealand', 2007, 4223800)
# (1427, 'New Zealand', 2008, 4259800)
# (1428, 'New Zealand', 2009, 4302600)
# (1429, 'New Zealand', 2010, 4350700)
# (1430, 'New Zealand', 2011, 4384000)
# (1431, 'New Zealand', 2012, 4408100)
# (1432, 'New Zealand', 2013, 4442100)
# (1433, 'New Zealand', 2014, 4516500)
# (1434, 'New Zealand', 2015, 4609400)
# (1435, 'New Zealand', 2016, 4714100)
# (1436, 'New Zealand', 2017, 4813600)
# (1437, 'New Zealand', 2018, 4900600)
# (1438, 'New Zealand', 2019, 4979200)
# (1439, 'New Zealand', 2020, 5090200)
# (1440, 'New Zealand', 2021, 5112800)
# (1441, 'Norway', 1950, 3265127)
# (1442, 'Norway', 1951, 3295871)
# (1443, 'Norway', 1952, 3327736)
# (1444, 'Norway', 1953, 3360892)
# (1445, 'Norway', 1954, 3394243)
# (1446, 'Norway', 1955, 3428210)
# (1447, 'Norway', 1956, 3460779)
# (1448, 'Norway', 1957, 3491935)
# (1449, 'Norway', 1958, 3522996)
# (1450, 'Norway', 1959, 3552852)
# (1451, 'Norway', 1960, 3581241)
# (1452, 'Norway', 1961, 3609801)
# (1453, 'Norway', 1962, 3638921)
# (1454, 'Norway', 1963, 3666538)
# (1455, 'Norway', 1964, 3694339)
# (1456, 'Norway', 1965, 3723172)
# (1457, 'Norway', 1966, 3753013)
# (1458, 'Norway', 1967, 3784533)
# (1459, 'Norway', 1968, 3816488)
# (1460, 'Norway', 1969, 3847710)
# (1461, 'Norway', 1970, 3875757)
# (1462, 'Norway', 1971, 3903034)
# (1463, 'Norway', 1972, 3933001)
# (1464, 'Norway', 1973, 3960614)
# (1465, 'Norway', 1974, 3985262)
# (1466, 'Norway', 1975, 4007319)
# (1467, 'Norway', 1976, 4026151)
# (1468, 'Norway', 1977, 4043204)
# (1469, 'Norway', 1978, 4058674)
# (1470, 'Norway', 1979, 4072514)
# (1471, 'Norway', 1980, 4085620)
# (1472, 'Norway', 1981, 4099703)
# (1473, 'Norway', 1982, 4114786)
# (1474, 'Norway', 1983, 4128434)
# (1475, 'Norway', 1984, 4140098)
# (1476, 'Norway', 1985, 4152518)
# (1477, 'Norway', 1986, 4167357)
# (1478, 'Norway', 1987, 4186905)
# (1479, 'Norway', 1988, 4209489)
# (1480, 'Norway', 1989, 4226909)
# (1481, 'Norway', 1990, 4241476)
# (1482, 'Norway', 1991, 4261738)
# (1483, 'Norway', 1992, 4286397)
# (1484, 'Norway', 1993, 4311984)
# (1485, 'Norway', 1994, 4336614)
# (1486, 'Norway', 1995, 4359187)
# (1487, 'Norway', 1996, 4381339)
# (1488, 'Norway', 1997, 4405158)
# (1489, 'Norway', 1998, 4431465)
# (1490, 'Norway', 1999, 4461915)
# (1491, 'Norway', 2000, 4490973)
# (1492, 'Norway', 2001, 4513747)
# (1493, 'Norway', 2002, 4538157)
# (1494, 'Norway', 2003, 4564856)
# (1495, 'Norway', 2004, 4591909)
# (1496, 'Norway', 2005, 4623293)
# (1497, 'Norway', 2006, 4660673)
# (1498, 'Norway', 2007, 4709156)
# (1499, 'Norway', 2008, 4768215)
# (1500, 'Norway', 2009, 4828716)
# (1501, 'Norway', 2010, 4889253)
# (1502, 'Norway', 2011, 4953089)
# (1503, 'Norway', 2012, 5018574)
# (1504, 'Norway', 2013, 5080171)
# (1505, 'Norway', 2014, 5137427)
# (1506, 'Norway', 2015, 5189898)
# (1507, 'Norway', 2016, 5236152)
# (1508, 'Norway', 2017, 5276965)
# (1509, 'Norway', 2018, 5311916)
# (1510, 'Norway', 2019, 5347893)
# (1511, 'Norway', 2020, 5379472)
# (1512, 'Norway', 2021, 5408320)
# (1513, 'Poland', 1950, 24824007)
# (1514, 'Poland', 1951, 25283013)
# (1515, 'Poland', 1952, 25764322)
# (1516, 'Poland', 1953, 26260482)
# ...
# (3343, 'Croatia', 1981, 4621419)
# (3344, 'Croatia', 1982, 4645413)
# (3345, 'Croatia', 1983, 4669614)
# (3346, 'Croatia', 1984, 4693431)
# (3347, 'Croatia', 1985, 4716117)
# (3348, 'Croatia', 1986, 4737948)
# (3349, 'Croatia', 1987, 4758151)
# (3350, 'Croatia', 1988, 4773682)
# (3351, 'Croatia', 1989, 4780628)
# (3352, 'Croatia', 1990, 4776374)
# (3353, 'Croatia', 1991, 4760003)
# (3354, 'Croatia', 1992, 4732862)
# (3355, 'Croatia', 1993, 4697538)
# (3356, 'Croatia', 1994, 4657803)
# (3357, 'Croatia', 1995, 4616766)
# (3358, 'Croatia', 1996, 4574888)
# (3359, 'Croatia', 1997, 4532401)
# (3360, 'Croatia', 1998, 4491907)
# (3361, 'Croatia', 1999, 4456437)
# (3362, 'Croatia', 2000, 4428075)
# (3363, 'Croatia', 2001, 4299642)
# (3364, 'Croatia', 2002, 4302174)
# (3365, 'Croatia', 2003, 4303399)
# (3366, 'Croatia', 2004, 4304600)
# (3367, 'Croatia', 2005, 4310145)
# (3368, 'Croatia', 2006, 4311159)
# (3369, 'Croatia', 2007, 4310217)
# (3370, 'Croatia', 2008, 4309705)
# (3371, 'Croatia', 2009, 4305181)
# (3372, 'Croatia', 2010, 4295427)
# (3373, 'Croatia', 2011, 4280622)
# (3374, 'Croatia', 2012, 4267558)
# (3375, 'Croatia', 2013, 4255689)
# (3376, 'Croatia', 2014, 4238389)
# (3377, 'Croatia', 2015, 4203604)
# (3378, 'Croatia', 2016, 4174349)
# (3379, 'Croatia', 2017, 4124531)
# (3380, 'Croatia', 2018, 4087843)
# (3381, 'Croatia', 2019, 4065253)
# (3382, 'Croatia', 2020, 4047680)
# (3383, 'Croatia', 2021, 4024898)
# (3384, 'Cyprus', 1950, 494018)
# (3385, 'Cyprus', 1951, 500384)
# (3386, 'Cyprus', 1952, 506630)
# (3387, 'Cyprus', 1953, 513429)
# (3388, 'Cyprus', 1954, 521186)
# (3389, 'Cyprus', 1955, 529970)
# (3390, 'Cyprus', 1956, 539568)
# (3391, 'Cyprus', 1957, 549465)
# (3392, 'Cyprus', 1958, 558897)
# (3393, 'Cyprus', 1959, 566969)
# (3394, 'Cyprus', 1960, 572933)
# (3395, 'Cyprus', 1961, 576402)
# (3396, 'Cyprus', 1962, 577696)
# (3397, 'Cyprus', 1963, 577918)
# (3398, 'Cyprus', 1964, 578628)
# (3399, 'Cyprus', 1965, 580972)
# (3400, 'Cyprus', 1966, 585313)
# (3401, 'Cyprus', 1967, 591301)
# (3402, 'Cyprus', 1968, 598495)
# (3403, 'Cyprus', 1969, 606121)
# (3404, 'Cyprus', 1970, 613618)
# (3405, 'Cyprus', 1971, 620860)
# (3406, 'Cyprus', 1972, 628002)
# (3407, 'Cyprus', 1973, 635105)
# (3408, 'Cyprus', 1974, 642322)
# (3409, 'Cyprus', 1975, 649753)
# (3410, 'Cyprus', 1976, 657524)
# (3411, 'Cyprus', 1977, 665521)
# (3412, 'Cyprus', 1978, 673253)
# (3413, 'Cyprus', 1979, 680010)
# (3414, 'Cyprus', 1980, 685408)
# (3415, 'Cyprus', 1981, 689170)
# (3416, 'Cyprus', 1982, 523734)
# (3417, 'Cyprus', 1983, 528071)
# (3418, 'Cyprus', 1984, 534958)
# (3419, 'Cyprus', 1985, 541502)
# (3420, 'Cyprus', 1986, 547747)
# (3421, 'Cyprus', 1987, 553736)
# (3422, 'Cyprus', 1988, 559639)
# (3423, 'Cyprus', 1989, 567674)
# (3424, 'Cyprus', 1990, 579898)
# (3425, 'Cyprus', 1991, 595105)
# (3426, 'Cyprus', 1992, 611151)
# (3427, 'Cyprus', 1993, 626087)
# (3428, 'Cyprus', 1994, 639170)
# (3429, 'Cyprus', 1995, 650860)
# (3430, 'Cyprus', 1996, 661326)
# (3431, 'Cyprus', 1997, 670764)
# (3432, 'Cyprus', 1998, 679042)
# (3433, 'Cyprus', 1999, 686675)
# (3434, 'Cyprus', 2000, 694020)
# (3435, 'Cyprus', 2001, 701537)
# (3436, 'Cyprus', 2002, 709631)
# (3437, 'Cyprus', 2003, 718305)
# (3438, 'Cyprus', 2004, 727977)
# (3439, 'Cyprus', 2005, 738541)
# (3440, 'Cyprus', 2006, 750964)
# (3441, 'Cyprus', 2007, 767128)
# (3442, 'Cyprus', 2008, 786630)
# (3443, 'Cyprus', 2009, 808038)
# (3444, 'Cyprus', 2010, 829444)
# (3445, 'Cyprus', 2011, 850882)
# (3446, 'Cyprus', 2012, 863945)
# (3447, 'Cyprus', 2013, 861938)
# (3448, 'Cyprus', 2014, 852511)
# (3449, 'Cyprus', 2015, 847662)
# (3450, 'Cyprus', 2016, 851559)
# (3451, 'Cyprus', 2017, 859520)
# (3452, 'Cyprus', 2018, 870071)
# (3453, 'Cyprus', 2019, 881949)
# (3454, 'Cyprus', 2020, 892828)
# (3455, 'Cyprus', 2021, 899939)
# (3456, 'Lithuania', 1950, 2567407)
# (3457, 'Lithuania', 1951, 2569617)
# (3458, 'Lithuania', 1952, 2578051)
# (3459, 'Lithuania', 1953, 2591374)
# (3460, 'Lithuania', 1954, 2608525)
# (3461, 'Lithuania', 1955, 2628752)
# (3462, 'Lithuania', 1956, 2651634)
# (3463, 'Lithuania', 1957, 2677006)
# (3464, 'Lithuania', 1958, 2704988)
# (3465, 'Lithuania', 1959, 2735866)
# (3466, 'Lithuania', 1960, 2769879)
# (3467, 'Lithuania', 1961, 2806924)
# (3468, 'Lithuania', 1962, 2846393)
# (3469, 'Lithuania', 1963, 2887072)
# (3470, 'Lithuania', 1964, 2927385)
# (3471, 'Lithuania', 1965, 2966165)
# (3472, 'Lithuania', 1966, 3002792)
# (3473, 'Lithuania', 1967, 3037458)
# (3474, 'Lithuania', 1968, 3070698)
# (3475, 'Lithuania', 1969, 3103509)
# (3476, 'Lithuania', 1970, 3139689)
# (3477, 'Lithuania', 1971, 3179041)
# (3478, 'Lithuania', 1972, 3213622)
# (3479, 'Lithuania', 1973, 3244438)
# (3480, 'Lithuania', 1974, 3273894)
# (3481, 'Lithuania', 1975, 3301652)
# (3482, 'Lithuania', 1976, 3328664)
# (3483, 'Lithuania', 1977, 3355036)
# (3484, 'Lithuania', 1978, 3379514)
# (3485, 'Lithuania', 1979, 3397842)
# (3486, 'Lithuania', 1980, 3413202)
# (3487, 'Lithuania', 1981, 3432947)
# (3488, 'Lithuania', 1982, 3457179)
# (3489, 'Lithuania', 1983, 3485192)
# (3490, 'Lithuania', 1984, 3514205)
# (3491, 'Lithuania', 1985, 3544543)
# (3492, 'Lithuania', 1986, 3578914)
# (3493, 'Lithuania', 1987, 3616367)
# (3494, 'Lithuania', 1988, 3655049)
# (3495, 'Lithuania', 1989, 3684255)
# (3496, 'Lithuania', 1990, 3697838)
# (3497, 'Lithuania', 1991, 3704134)
# (3498, 'Lithuania', 1992, 3700114)
# (3499, 'Lithuania', 1993, 3682613)
# (3500, 'Lithuania', 1994, 3657144)
# (3501, 'Lithuania', 1995, 3629102)
# (3502, 'Lithuania', 1996, 3601613)
# (3503, 'Lithuania', 1997, 3575137)
# (3504, 'Lithuania', 1998, 3549331)
# (3505, 'Lithuania', 1999, 3524237)
# (3506, 'Lithuania', 2000, 3499534)
# (3507, 'Lithuania', 2001, 3470817)
# (3508, 'Lithuania', 2002, 3443066)
# (3509, 'Lithuania', 2003, 3415209)
# (3510, 'Lithuania', 2004, 3377073)
# (3511, 'Lithuania', 2005, 3322525)
# (3512, 'Lithuania', 2006, 3269903)
# (3513, 'Lithuania', 2007, 3231297)
# (3514, 'Lithuania', 2008, 3198234)
# (3515, 'Lithuania', 2009, 3162911)
# (3516, 'Lithuania', 2010, 3097292)
# (3517, 'Lithuania', 2011, 3028119)
# (3518, 'Lithuania', 2012, 2987773)
# (3519, 'Lithuania', 2013, 2957689)
# (3520, 'Lithuania', 2014, 2932366)
# (3521, 'Lithuania', 2015, 2904908)
# (3522, 'Lithuania', 2016, 2868234)
# (3523, 'Lithuania', 2017, 2828398)
# (3524, 'Lithuania', 2018, 2801541)
# (3525, 'Lithuania', 2019, 2794135)
# (3526, 'Lithuania', 2020, 2794890)
# (3527, 'Lithuania', 2021, 2795321)
# (3528, 'Malta', 1950, 311998)
# (3529, 'Malta', 1951, 312215)
# (3530, 'Malta', 1952, 312746)
# (3531, 'Malta', 1953, 313266)
# (3532, 'Malta', 1954, 313562)
# (3533, 'Malta', 1955, 313523)
# (3534, 'Malta', 1956, 313195)
# (3535, 'Malta', 1957, 312702)
# (3536, 'Malta', 1958, 312303)
# (3537, 'Malta', 1959, 312316)
# (3538, 'Malta', 1960, 312973)
# (3539, 'Malta', 1961, 314414)
# (3540, 'Malta', 1962, 316520)
# (3541, 'Malta', 1963, 318888)
# (3542, 'Malta', 1964, 320927)
# (3543, 'Malta', 1965, 322238)
# (3544, 'Malta', 1966, 322696)
# (3545, 'Malta', 1967, 322457)
# (3546, 'Malta', 1968, 321762)
# (3547, 'Malta', 1969, 321031)
# (3548, 'Malta', 1970, 320548)
# (3549, 'Malta', 1971, 320364)
# (3550, 'Malta', 1972, 320437)
# (3551, 'Malta', 1973, 320801)
# (3552, 'Malta', 1974, 321436)
# (3553, 'Malta', 1975, 322358)
# (3554, 'Malta', 1976, 323579)
# (3555, 'Malta', 1977, 325126)
# (3556, 'Malta', 1978, 326984)
# (3557, 'Malta', 1979, 329117)
# (3558, 'Malta', 1980, 331494)
# (3559, 'Malta', 1981, 334115)
# (3560, 'Malta', 1982, 336964)
# (3561, 'Malta', 1983, 339984)
# (3562, 'Malta', 1984, 330593)
# (3563, 'Malta', 1985, 336452)
# (3564, 'Malta', 1986, 342121)
# (3565, 'Malta', 1987, 344485)
# (3566, 'Malta', 1988, 347325)
# (3567, 'Malta', 1989, 350722)
# (3568, 'Malta', 1990, 354170)
# (3569, 'Malta', 1991, 357727)
# (3570, 'Malta', 1992, 361260)
# (3571, 'Malta', 1993, 364704)
# (3572, 'Malta', 1994, 367941)
# (3573, 'Malta', 1995, 370433)
# (3574, 'Malta', 1996, 372687)
# (3575, 'Malta', 1997, 375236)
# (3576, 'Malta', 1998, 377516)
# (3577, 'Malta', 1999, 379360)
# (3578, 'Malta', 2000, 385808)
# (3579, 'Malta', 2001, 393028)
# (3580, 'Malta', 2002, 395969)
# (3581, 'Malta', 2003, 398582)
# (3582, 'Malta', 2004, 401263)
# (3583, 'Malta', 2005, 403825)
# (3584, 'Malta', 2006, 405311)
# (3585, 'Malta', 2007, 406725)
# (3586, 'Malta', 2008, 409377)
# (3587, 'Malta', 2009, 412474)
# (3588, 'Malta', 2010, 414509)
# (3589, 'Malta', 2011, 416264)
# (3590, 'Malta', 2012, 420033)
# (3591, 'Malta', 2013, 425968)
# (3592, 'Malta', 2014, 434557)
# (3593, 'Malta', 2015, 445056)
# (3594, 'Malta', 2016, 455356)
# (3595, 'Malta', 2017, 468005)
# (3596, 'Malta', 2018, 484634)
# (3597, 'Malta', 2019, 504059)
# (3598, 'Malta', 2020, 515330)
# (3599, 'Malta', 2021, 516748)
# (3600, 'Romania', 1950, 16236289)
# (3601, 'Romania', 1951, 16512670)
# (3602, 'Romania', 1952, 16764911)
# (3603, 'Romania', 1953, 17005719)
# (3604, 'Romania', 1954, 17243812)
# (3605, 'Romania', 1955, 17483935)
# (3606, 'Romania', 1956, 17726634)
# (3607, 'Romania', 1957, 17968470)
# (3608, 'Romania', 1958, 18202715)
# (3609, 'Romania', 1959, 18420450)
# (3610, 'Romania', 1960, 18613945)
# (3611, 'Romania', 1961, 18780210)
# (3612, 'Romania', 1962, 18924152)
# (3613, 'Romania', 1963, 19059934)
# (3614, 'Romania', 1964, 19207139)
# (3615, 'Romania', 1965, 19379575)
# (3616, 'Romania', 1966, 19582332)
# (3617, 'Romania', 1967, 19810612)
# (3618, 'Romania', 1968, 19799831)
# (3619, 'Romania', 1969, 20009141)
# (3620, 'Romania', 1970, 20250396)
# (3621, 'Romania', 1971, 20461575)
# (3622, 'Romania', 1972, 20657956)
# (3623, 'Romania', 1973, 20835682)
# (3624, 'Romania', 1974, 21029428)
# (3625, 'Romania', 1975, 21293586)
# (3626, 'Romania', 1976, 21551631)
# (3627, 'Romania', 1977, 21756097)
# (3628, 'Romania', 1978, 21951467)
# (3629, 'Romania', 1979, 22090484)
# (3630, 'Romania', 1980, 22207284)
# (3631, 'Romania', 1981, 22353071)
# (3632, 'Romania', 1982, 22475742)
# (3633, 'Romania', 1983, 22560476)
# (3634, 'Romania', 1984, 22640545)
# (3635, 'Romania', 1985, 22732997)
# (3636, 'Romania', 1986, 22836836)
# (3637, 'Romania', 1987, 22949427)
# (3638, 'Romania', 1988, 23057660)
# (3639, 'Romania', 1989, 23161460)
# (3640, 'Romania', 1990, 23201832)
# (3641, 'Romania', 1991, 23001160)
# (3642, 'Romania', 1992, 22794284)
# (3643, 'Romania', 1993, 22763283)
# (3644, 'Romania', 1994, 22730216)
# (3645, 'Romania', 1995, 22684268)
# (3646, 'Romania', 1996, 22619005)
# (3647, 'Romania', 1997, 22553982)
# (3648, 'Romania', 1998, 22507354)
# (3649, 'Romania', 1999, 22472043)
# (3650, 'Romania', 2000, 22442973)
# (3651, 'Romania', 2001, 22131974)
# (3652, 'Romania', 2002, 21675775)
# (3653, 'Romania', 2003, 21574365)
# (3654, 'Romania', 2004, 21451845)
# (3655, 'Romania', 2005, 21319673)
# (3656, 'Romania', 2006, 21193749)
# (3657, 'Romania', 2007, 20882980)
# (3658, 'Romania', 2008, 20537848)
# (3659, 'Romania', 2009, 20367437)
# (3660, 'Romania', 2010, 20246798)
# (3661, 'Romania', 2011, 20147657)
# (3662, 'Romania', 2012, 20060182)
# (3663, 'Romania', 2013, 19988694)
# (3664, 'Romania', 2014, 19916451)
# (3665, 'Romania', 2015, 19822250)
# (3666, 'Romania', 2016, 19706424)
# (3667, 'Romania', 2017, 19592933)
# (3668, 'Romania', 2018, 19476713)
# (3669, 'Romania', 2019, 19375835)
# (3670, 'Romania', 2020, 19269469)
# (3671, 'Romania', 2021, 19136038)
# (3672, 'Saudi Arabia', 1950, 3121340)
# (3673, 'Saudi Arabia', 1951, 3198811)
# (3674, 'Saudi Arabia', 1952, 3283593)
# (3675, 'Saudi Arabia', 1953, 3372837)
# (3676, 'Saudi Arabia', 1954, 3464662)
# (3677, 'Saudi Arabia', 1955, 3558165)
# (3678, 'Saudi Arabia', 1956, 3653505)
# (3679, 'Saudi Arabia', 1957, 3751798)
# (3680, 'Saudi Arabia', 1958, 3855030)
# (3681, 'Saudi Arabia', 1959, 3965799)
# (3682, 'Saudi Arabia', 1960, 4086534)
# (3683, 'Saudi Arabia', 1961, 4218852)
# (3684, 'Saudi Arabia', 1962, 4362788)
# (3685, 'Saudi Arabia', 1963, 4516540)
# (3686, 'Saudi Arabia', 1964, 4677304)
# (3687, 'Saudi Arabia', 1965, 4843632)
# (3688, 'Saudi Arabia', 1966, 5015353)
# (3689, 'Saudi Arabia', 1967, 5195124)
# (3690, 'Saudi Arabia', 1968, 5387822)
# (3691, 'Saudi Arabia', 1969, 5599909)
# (3692, 'Saudi Arabia', 1970, 5836388)
# (3693, 'Saudi Arabia', 1971, 6100631)
# (3694, 'Saudi Arabia', 1972, 6392973)
# (3695, 'Saudi Arabia', 1973, 6711922)
# (3696, 'Saudi Arabia', 1974, 7054532)
# (3697, 'Saudi Arabia', 1975, 7419486)
# (3698, 'Saudi Arabia', 1976, 7802928)
# (3699, 'Saudi Arabia', 1977, 8207695)
# (3700, 'Saudi Arabia', 1978, 8646845)
# (3701, 'Saudi Arabia', 1979, 9137928)
# (3702, 'Saudi Arabia', 1980, 9691471)
# (3703, 'Saudi Arabia', 1981, 10311771)
# (3704, 'Saudi Arabia', 1982, 10988851)
# (3705, 'Saudi Arabia', 1983, 11701132)
# (3706, 'Saudi Arabia', 1984, 12418836)
# (3707, 'Saudi Arabia', 1985, 13118998)
# (3708, 'Saudi Arabia', 1986, 13794167)
# (3709, 'Saudi Arabia', 1987, 14445663)
# (3710, 'Saudi Arabia', 1988, 15070082)
# (3711, 'Saudi Arabia', 1989, 15666289)
# (3712, 'Saudi Arabia', 1990, 16233786)
# (3713, 'Saudi Arabia', 1991, 16772695)
# (3714, 'Saudi Arabia', 1992, 17282686)
# (3715, 'Saudi Arabia', 1993, 17763297)
# (3716, 'Saudi Arabia', 1994, 18214475)
# (3717, 'Saudi Arabia', 1995, 18638790)
# (3718, 'Saudi Arabia', 1996, 19033843)
# (3719, 'Saudi Arabia', 1997, 19407138)
# (3720, 'Saudi Arabia', 1998, 19783301)
# (3721, 'Saudi Arabia', 1999, 20194531)
# (3722, 'Saudi Arabia', 2000, 20663840)
# (3723, 'Saudi Arabia', 2001, 21202646)
# (3724, 'Saudi Arabia', 2002, 21805322)
# (3725, 'Saudi Arabia', 2003, 22456645)
# (3726, 'Saudi Arabia', 2004, 23132686)
# (3727, 'Saudi Arabia', 2005, 23816175)
# (3728, 'Saudi Arabia', 2006, 24498313)
# (3729, 'Saudi Arabia', 2007, 25184589)
# (3730, 'Saudi Arabia', 2008, 25888535)
# (3731, 'Saudi Arabia', 2009, 26630303)
# (3732, 'Saudi Arabia', 2010, 27421468)
# (3733, 'Saudi Arabia', 2011, 28267591)
# (3734, 'Saudi Arabia', 2012, 29154906)
# (3735, 'Saudi Arabia', 2013, 30052058)
# (3736, 'Saudi Arabia', 2014, 30916603)
# (3737, 'Saudi Arabia', 2015, 31717676)
# (3738, 'Saudi Arabia', 2016, 31787580)
# (3739, 'Saudi Arabia', 2017, 32612641)
# (3740, 'Saudi Arabia', 2018, 33413660)
# (3741, 'Saudi Arabia', 2019, 34218169)
# (3742, 'Saudi Arabia', 2020, 35013414)
# (3743, 'Saudi Arabia', 2021, 34110821)
# (3744, 'Singapore', 1950, 1022095)
# (3745, 'Singapore', 1951, 1067797)
# (3746, 'Singapore', 1952, 1119932)
# (3747, 'Singapore', 1953, 1177580)
# (3748, 'Singapore', 1954, 1239692)
# (3749, 'Singapore', 1955, 1305103)
# (3750, 'Singapore', 1956, 1372516)
# (3751, 'Singapore', 1957, 1440490)
# (3752, 'Singapore', 1958, 1507544)
# (3753, 'Singapore', 1959, 1572174)
# (3754, 'Singapore', 1960, 1646400)
# (3755, 'Singapore', 1961, 1702400)
# (3756, 'Singapore', 1962, 1750200)
# (3757, 'Singapore', 1963, 1795000)
# (3758, 'Singapore', 1964, 1841600)
# (3759, 'Singapore', 1965, 1886900)
# (3760, 'Singapore', 1966, 1934400)
# (3761, 'Singapore', 1967, 1977600)
# (3762, 'Singapore', 1968, 2012000)
# (3763, 'Singapore', 1969, 2042500)
# (3764, 'Singapore', 1970, 2013563)
# (3765, 'Singapore', 1971, 2112900)
# (3766, 'Singapore', 1972, 2152400)
# (3767, 'Singapore', 1973, 2193000)
# (3768, 'Singapore', 1974, 2229800)
# (3769, 'Singapore', 1975, 2262600)
# (3770, 'Singapore', 1976, 2293300)
# (3771, 'Singapore', 1977, 2325300)
# (3772, 'Singapore', 1978, 2353600)
# (3773, 'Singapore', 1979, 2383500)
# (3774, 'Singapore', 1980, 2282125)
# (3775, 'Singapore', 1981, 2324403)
# (3776, 'Singapore', 1982, 2365707)
# (3777, 'Singapore', 1983, 2406165)
# (3778, 'Singapore', 1984, 2443705)
# (3779, 'Singapore', 1985, 2482615)
# (3780, 'Singapore', 1986, 2518598)
# (3781, 'Singapore', 1987, 2553864)
# (3782, 'Singapore', 1988, 2598458)
# (3783, 'Singapore', 1989, 2647627)
# (3784, 'Singapore', 1990, 2735868)
# (3785, 'Singapore', 1991, 2794704)
# (3786, 'Singapore', 1992, 2849754)
# (3787, 'Singapore', 1993, 2904547)
# (3788, 'Singapore', 1994, 2959350)
# (3789, 'Singapore', 1995, 3013515)
# (3790, 'Singapore', 1996, 3068132)
# (3791, 'Singapore', 1997, 3123403)
# (3792, 'Singapore', 1998, 3180018)
# (3793, 'Singapore', 1999, 3229681)
# (3794, 'Singapore', 2000, 3273363)
# (3795, 'Singapore', 2001, 3325902)
# (3796, 'Singapore', 2002, 3382944)
# (3797, 'Singapore', 2003, 3366891)
# (3798, 'Singapore', 2004, 3413266)
# (3799, 'Singapore', 2005, 3467814)
# (3800, 'Singapore', 2006, 3525894)
# (3801, 'Singapore', 2007, 3583082)
# (3802, 'Singapore', 2008, 3642659)
# (3803, 'Singapore', 2009, 3733876)
# (3804, 'Singapore', 2010, 3771721)
# (3805, 'Singapore', 2011, 3789251)
# (3806, 'Singapore', 2012, 3818205)
# (3807, 'Singapore', 2013, 3844751)
# (3808, 'Singapore', 2014, 3870739)
# (3809, 'Singapore', 2015, 3902690)
# (3810, 'Singapore', 2016, 3933559)
# (3811, 'Singapore', 2017, 3965796)
# (3812, 'Singapore', 2018, 3994283)
# (3813, 'Singapore', 2019, 4026209)
# (3814, 'Singapore', 2020, 4044210)

# %% [markdown]
# # Conversion du résultat en dataframe

# %%
dataframe = pd.DataFrame(population_country, columns = ['id', 'countrie', 'year', 'population'])

# %% [markdown]
# # Bonus : exportation en format .csv

# %%
dataframe.to_csv('breaf5-dataframe', index=False, encoding='utf-8')

# %%
data_breaf = pd.read_csv('breaf5-dataframe', index_col=False)
data_breaf.head()
# Out:
#    id   countrie  year  population
# 0   1  Australia  1950     8178700
# 1   2  Australia  1951     8421700
# 2   3  Australia  1952     8636500
# 3   4  Australia  1953     8815300
# 4   5  Australia  1954     8986500
