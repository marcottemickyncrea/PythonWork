# %% [markdown]
# # Scipy

# %% [markdown]
# https://www.youtube.com/watch?v=P0Xr5TIML8U&list=PLO_fdPEVlfKqMDNmCFzQISI2H_nJcEDJq&index=17

# %% [markdown]
# calculs scientifiques

# %% [markdown]
# ## Interpolate

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 10)
y = x**2
plt.scatter(x, y)

# %%
from scipy.interpolate import interp1d

# %%
f = interp1d(x, y, kind = 'linear')

new_x = np.linspace(0, 10, 30)
result = f(new_x)

plt.scatter(x, y)
plt.scatter(new_x, result, c='r')

# %% [markdown]
# ## Optimize

# %% [markdown]
# fait plus souvent appel à des problème de minimisation

# %%
x = np.linspace(0 ,2, 100)
y = 1/3 * x**3 - 3/5 * x**2 +2 + np.random.randn(x.shape[0])/20
plt.scatter(x, y)

# %%
def f(x, a ,b ,c, d):
    return a * x**3 + b * x**2 + c * x + d

# %%
from scipy import optimize

# %%
params, param_cov = optimize.curve_fit(f, x, y)

# %%
plt.scatter(x, y)
plt.plot(x, f(x, params[0], params[1],params[2], params[3]), c='r', lw=3)

# %% [markdown]
# ## Minimize

# %%
def f (x):
    return x**2 + 15*np.sin(x)

# %%
x = np.linspace(-10, 10, 100)
plt.plot(x, f(x))

# %%
x0=-5
result = optimize.minimize(f, x0 = x0).x
result
# Out:
# array([-1.38505583])

# %%
plt.plot(x, f(x), lw=3, zorder=-1)
plt.scatter(result, f(result), s=100, c='r', zorder=1)
plt.scatter(x0, f(x0), s=200, marker='+', c='g', zorder=1)

# %% [markdown]
# ## Traitement du signal

# %%
x = np.linspace(0, 20 ,100)
y = x + 4*np.sin(x) + np.random.randn(x.shape[0])
plt.plot(x, y)

# %%
from scipy import signal

# %%
new_y = signal.detrend(y)

# %%
plt.plot(x, y)
plt.plot(x, new_y)

# %% [markdown]
# ## Transformation de Fourier

# %% [markdown]
# extrait et analyse les fréquences présente dans un signal périodique

# %%
x = np.linspace(0, 30 ,100)
y = 3 * np.sin(x) + 2*np.sin(5 * x) + np.sin(10*x)
plt.plot(x, y)

# %%
from scipy import fftpack

# %%
fourier = fftpack.fft(y)
power = np.abs(fourier)
frequences = fftpack.fftfreq(y.size)
plt.plot(np.abs(frequences), power)
