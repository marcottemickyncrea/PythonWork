# %% [markdown]
# # Initiation à Matplotlib

# %% [markdown]
# permet de tracer des graphiques super convainquant

# %% [markdown]
# attention : ne pas mélanger les deux méthodes proposées par matplolib => créé des bugs !

# %%
import numpy as np

# %%
x = np.linspace(0, 2, 10)
y = x**2
print(x)
print(y)
# Out:
# [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]
# [0.         0.04938272 0.19753086 0.44444444 0.79012346 1.2345679
#  1.77777778 2.41975309 3.16049383 4.        ]

# %% [markdown]
# ## pyplot (fonction)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# attention : x et y doivent avoir le même nombre de points => renvoie une erreur dans le cas contraire

# %%
plt.plot(x, y)
#plt.show() si on ne travaille pas dans notebook jupiter

# %%
plt.scatter(x, y) #nuage de points

# %% [markdown]
# ### customiser une courbe

# %%
plt.plot(x, y, c='red', lw=3, ls='--')
# c = couleur de la courbe
# lw = épaisseur de la courbe
# ls = aspect de la courbe

# %% [markdown]
# ### Cycle de vie d'une figure

# %%
plt.figure(figsize=(12, 8)) # créé une page blanche qui permet de modifier la taille du graphique
plt.plot(x , y, label='quadratique') # label donne un nom à la courbe
plt.plot(x, x**3, label='cubique')
plt.title('figure 1') #donne un titre au graphique
plt.xlabel('axe X') #titre à l'axe des X
plt.ylabel('axe Y') #titre à l'axe des Y
plt.legend() #légende
plt.savefig('cycle de vie') #enregistre le fichier sur l'ordi

# %% [markdown]
# ## Créer plusieurs graphiques

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x , y , c='red')
plt.title('graph 1')
plt.subplot(2,2,2)
plt.plot(x, y, c='purple')
plt.subplot(2, 2, 3)
plt.plot(x , y , c='blue')
plt.subplot(2,2,4)
plt.plot(x, y, c='green')
plt.title('grap 4')
# Out:
# Text(0.5, 1.0, 'grap 4')

# %% [markdown]
# ## OOP (orienté objet)

# %% [markdown]
# déconseillé => 99% peut être réalisé avec pyplot <br/>
# mais offre plus de possibilité

# %%
fig, ax = plt.subplots() #créer un tableau
ax.plot(x, y)

# %%
fig, ax = plt.subplots(2, 1, sharex=True)
ax[0].plot(x, y, c='red')
ax[1].plot(x, np.sin(x), c='green')

# %% [markdown]
# ### exercice

# %%
dataset = {f"experience{i}": np.random.randn(100) for i in range(4)}
dataset['experience0']
# Out:
# array([ 1.20444319, -0.42873325,  0.82442814, -1.74604418, -1.01147344,
#        -0.36231793, -0.52897963, -0.60366018,  1.56840587, -0.63212508,
#         1.52209608,  0.2289982 ,  0.57336065, -1.51889296, -0.89198799,
#         0.40383482, -0.23863287,  0.44628349, -0.93310677, -1.94895947,
#         1.16746477, -1.65621083,  0.09904511,  0.64921203, -0.05088766,
#        -0.51872495, -0.02117224, -1.8975543 ,  0.24873304,  0.18649371,
#         0.23419458, -2.00725089, -0.14335824, -2.21877458, -0.7625806 ,
#         1.42017414, -0.19737347, -0.36444693, -1.06263625, -1.21219094,
#        -0.90480859,  2.54821902,  0.387867  , -0.65315854,  0.08815667,
#         1.03551176,  1.90520859, -0.37282952,  1.41654685, -1.8035122 ,
#        -0.75504848, -0.28722226, -2.08840191, -0.57470503,  0.89295816,
#        -0.02819908,  0.01960878, -1.04562534,  1.11280332,  1.02554046,
#         0.2800068 , -0.4867746 , -2.10502412,  0.30735265, -2.31121143,
#         0.0132372 ,  1.74134742, -0.39914082, -0.71921721,  0.16755984,
#        -0.71895862,  0.66328946,  0.01765249,  0.83309738,  0.97786166,
#         0.8231448 ,  0.17805285, -0.89467147,  2.12688921, -0.91559793,
#        -1.22205046, -0.33653792,  1.55784141, -0.03347347,  1.15590247,
#        -0.59634906,  0.32286133,  2.37309627, -0.69667982,  2.08367634,
#        -1.17213174, -0.47484411, -1.88658384,  0.43702786,  0.68169862,
#         0.50856272, -0.16821614,  0.01266781, -1.92261306, -1.6633403 ])

# %%
def graphique(data):
    plt.figure(figsize=(12, 8))
    n = len(data)
    for i in data:
        plt.subplot(n, 1, int(i[-1]) +1)
        plt.plot([j for j in range(len(data[i]))], data[i])
        plt.title(i) 
graphique(dataset)

# %%
#correction
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12,8))
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k])
        plt.title(k)
graphique(dataset)
